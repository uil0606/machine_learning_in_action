# %%
# 获取包
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression as LR
from sklearn.metrics import roc_curve,auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

import xgboost as xgb

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',300)

# %%
# 读取训练集数据
tr_user=pd.read_csv('./data/train/user_info_train.txt',header=None,names=['id','性别','职业','教育程度','婚姻状态','户口类型'])
tr_bank=pd.read_csv('./data/train/bank_detail_train.txt',header=None,names=['id','时间戳','交易类型','交易金额','工资收入标记'])
tr_browse=pd.read_csv('./data/train/browse_history_train.txt',header=None,names=['id','时间戳','浏览行为数据','浏览子行为编号'])
tr_bill=pd.read_csv('./data/train/bill_detail_train.txt',header=None,names=['id','时间戳','银行id','上期账单金额','上期还款金额','信用卡额度','本期账单余额','本期账单最低还款额','消费笔数','本期账单金额','调整金额','循环利息','可用金额','预借现金额度','还款状态'])
tr_loan=pd.read_csv('./data/train/loan_time_train.txt',header=None,names=['id','放款时间'])
tr_overdue=pd.read_csv('./data/train/overdue_train.txt',header=None,names=['id','label'])

# 读取测试集数据
te_user=pd.read_csv('./data/test/user_info_test.txt',header=None,names=['id','性别','职业','教育程度','婚姻状态','户口类型'])
te_bank=pd.read_csv('./data/test/bank_detail_test.txt',header=None,names=['id','时间戳','交易类型','交易金额','工资收入标记'])
te_browse=pd.read_csv('./data/test/browse_history_test.txt',header=None,names=['id','时间戳','浏览行为数据','浏览子行为编号'])
te_bill=pd.read_csv('./data/test/bill_detail_test.txt',header=None,names=['id','时间戳','银行id','上期账单金额','上期还款金额','信用卡额度','本期账单余额','本期账单最低还款额','消费笔数','本期账单金额','调整金额','循环利息','可用金额','预借现金额度','还款状态'])
te_loan=pd.read_csv('./data/test/loan_time_test.txt',header=None,names=['id','放款时间'])
te_id=pd.read_csv('./data/test/usersID_test.txt',header=None,names=['id'])

# 时间转换
for i in [tr_bank,tr_browse,tr_bill,te_bank,te_browse,te_bill]:
    i['时间戳']=i['时间戳']/86400
tr_loan['放款时间']=tr_loan['放款时间']/86400
te_loan['放款时间']=te_loan['放款时间']/86400

# %%
# 计算ks值，作图
def plot_ks_curve(df):
    df.columns=['labels','pred']
    df=df.sort_values(by=['pred','labels'],axis=0,ascending=[False,True])
    df=df.reset_index(drop=True)
    bad_cnt=df['labels'].sum()
    good_cnt=len(df)-bad_cnt

    df['acc_bad']=df['labels'].cumsum()
    df['acc_good']=(1-df['labels']).cumsum()
    df['acc_bad_rate']=df['acc_bad']/bad_cnt
    df['acc_good_rate']=df['acc_good']/good_cnt
    df['ks']=df['acc_bad_rate']-df['acc_good_rate']

    ks_max=df['ks'].max()
#     print(df.loc[df['ks']==ks_max,:])

    # auc
    fpr,tpr,threshold=roc_curve(df['labels'],df['pred'],pos_label=1)
    roc_auc = auc(fpr, tpr)
    print('auc_value:',roc_auc)
    print('ks_values:',ks_max)

#     x_=np.linspace(0,1,len(df))
#     plt.figure(figsize=(8, 8))
#     plt.plot(x_,df['acc_bad_rate'],color='red',label='tpr')
#     plt.plot(x_,df['acc_good_rate'],color='blue',label='fpr')
#     plt.plot(x_,df['ks'],color='yellow',label='ks_values (max = %0.2f)' % ks_max)
#     plt.xlabel('Customer cumulative proportion')
#     plt.title('KS curve')
#     plt.legend(loc='upper left')
#     plt.show()
    return roc_auc,ks_max

def mon_distance(x):
    if x is np.nan:
        return 100
    else:
        return int(x/30)

# %%
# 用户表特征
def user(df):
    fea_u=df[['id']].copy()
    gender_dummy=pd.get_dummies(df[['性别']].astype(str))
    work_dummy=pd.get_dummies(df[['职业']].astype(str))
    edu_dummy=pd.get_dummies(df[['教育程度']].astype(str))
    marital_dummy=pd.get_dummies(df[['婚姻状态']].astype(str))
    reg_dummy=pd.get_dummies(df[['户口类型']].astype(str))

    fea_u=pd.concat([fea_u,gender_dummy,work_dummy,edu_dummy,marital_dummy,reg_dummy],axis=1)
    
#     print('feature of user',fea_u.columns.tolist())
    return fea_u

# %%
# 贷前银行流水特征
def bef_bank(df,df_loan):
    df=pd.merge(df,df_loan,how='left',on='id',suffixes=['','_loan'])
    df=df[df['放款时间']>df['时间戳']]
    df['mon_dist']=(df['放款时间']-df['时间戳']).map(mon_distance)
    
    # id 列表
    fea_bank=df[['id']].drop_duplicates().copy()
    
    # 平均每次工资收入金额
    b1=df[(df['mon_dist']>=0) & (df['工资收入标记']==1)][['id','交易金额']].copy()
    b1=b1.groupby('id',as_index=False).agg('mean')
    b1=b1.rename(columns={'交易金额':'bef_bank_salary_ave'})
    # 收入总额
    b2=df[(df['mon_dist']>=0) & (df['交易类型']==0)][['id','交易金额']].copy()
    b2=b2.groupby('id',as_index=False).agg('sum')
    b2=b2.rename(columns={'交易金额':'bef_bank_inc_sum'})

    # 支出总额
    b3=df[(df['mon_dist']>=0) & (df['交易类型']==1)][['id','交易金额']].copy()
    b3=b3.groupby('id',as_index=False).agg('sum')
    b3=b3.rename(columns={'交易金额':'bef_bank_out_sum'})
    
    # 近3月总收入
    b4=df[(df['mon_dist']>=0) & (df['mon_dist']<=3) & (df['交易类型']==0)][['id','交易金额']].copy()
    b4=b4.groupby('id',as_index=False).agg('sum')
    b4=b4.rename(columns={'交易金额':'bef_bank_inc_m3_sum'})
    
    # 近3月总支出
    b5=df[(df['mon_dist']>=0) & (df['mon_dist']<=3) & (df['交易类型']==1)][['id','交易金额']].copy()
    b5=b5.groupby('id',as_index=False).agg('sum')
    b5=b5.rename(columns={'交易金额':'bef_bank_out_m3_sum'})   
    
    # 工资收入总额
    b6=df[(df['mon_dist']>=0) & (df['工资收入标记']==1)][['id','交易金额']].copy()
    b6=b6.groupby('id',as_index=False).agg('sum')
    b6=b6.rename(columns={'交易金额':'bef_bank_salary_sum'})    
    
    # 近3月收入笔数
    b7=df[(df['mon_dist']>=0) & (df['mon_dist']<=3) & (df['交易类型']==0)][['id','交易金额']].copy()
    b7=b7.groupby('id',as_index=False).agg('count')
    b7=b7.rename(columns={'交易金额':'bef_bank_inc_m3_count'})

    # 近3月支出笔数
    b8=df[(df['mon_dist']>=0) & (df['mon_dist']<=3) & (df['交易类型']==1)][['id','交易金额']].copy()
    b8=b8.groupby('id',as_index=False).agg('count')
    b8=b8.rename(columns={'交易金额':'bef_bank_out_m3_count'}) 
    
    # 近3月收入单次最大额
    b9=df[(df['mon_dist']>=0) & (df['mon_dist']<=3) & (df['交易类型']==0)][['id','交易金额']].copy()
    b9=b9.groupby('id',as_index=False).agg('max')
    b9=b9.rename(columns={'交易金额':'bef_bank_inc_m3_max'}) 

    # 近3月收入单次最小额
    b10=df[(df['mon_dist']>=0) & (df['mon_dist']<=3) & (df['交易类型']==0)][['id','交易金额']].copy()
    b10=b10.groupby('id',as_index=False).agg('min')
    b10=b10.rename(columns={'交易金额':'bef_bank_inc_m3_min'}) 
        
    # 近1月总收入
    b11=df[(df['mon_dist']>=0) & (df['mon_dist']<=1) & (df['交易类型']==0)][['id','交易金额']].copy()
    b11=b11.groupby('id',as_index=False).agg('sum')
    b11=b11.rename(columns={'交易金额':'bef_bank_inc_m1_sum'})
    
    # 近1月总支出
    b12=df[(df['mon_dist']>=0) & (df['mon_dist']<=1) & (df['交易类型']==1)][['id','交易金额']].copy()
    b12=b12.groupby('id',as_index=False).agg('sum')
    b12=b12.rename(columns={'交易金额':'bef_bank_out_m1_sum'})   
    
    # 近3月收入方差
    b13=df[(df['mon_dist']>=0) & (df['mon_dist']<=3)&(df['交易类型']==0)][['id','交易金额']].copy()
    b13=b13.groupby('id',as_index=False).agg('std')
    b13=b13.rename(columns={'交易金额':'bef_bank_inc_m3_std'})
    
       
    # 合并特征
    for i in [b1,b2,b3,b4,b5,b6,b7,b8,b9,b10,b11,b12,b13]:
        fea_bank=pd.merge(fea_bank,i,how='left',on='id')
    
    # 近3月净收入
    fea_bank['bef_bank_ninc_m3_sum']=fea_bank['bef_bank_inc_m3_sum']-fea_bank['bef_bank_out_m3_sum']
    # 收入中工资占比
    fea_bank['bef_bank_salary_inc_rate']=fea_bank['bef_bank_salary_sum']/fea_bank['bef_bank_inc_sum']
    
    fea_bank=fea_bank.fillna(-1)
      
    
#     print('feature of bef bank detail',fea_bank.columns.tolist())
    return fea_bank

# %%
# 贷后银行流水特征
def aft_bank(df,df_loan):
    df=pd.merge(df,df_loan,how='left',on='id',suffixes=['','_loan'])
    df=df[df['放款时间']<=df['时间戳']]
    df['mon_dist']=(df['放款时间']-df['时间戳']).map(mon_distance)
    
    # id 列表
    fea_bank=df[['id']].drop_duplicates().copy()
    
#     # 平均每次工资收入金额
#     b1=df[(df['mon_dist']<=0) & (df['工资收入标记']==1)][['id','交易金额']].copy()
#     b1=b1.groupby('id',as_index=False).agg('mean')
#     b1=b1.rename(columns={'交易金额':'aft_bank_salary_ave'})
    # 收入总额
    b2=df[(df['mon_dist']<=0) & (df['交易类型']==0)][['id','交易金额']].copy()
    b2=b2.groupby('id',as_index=False).agg('sum')
    b2=b2.rename(columns={'交易金额':'aft_bank_inc_sum'})

    # 支出总额
    b3=df[(df['mon_dist']<=0) & (df['交易类型']==1)][['id','交易金额']].copy()
    b3=b3.groupby('id',as_index=False).agg('sum')
    b3=b3.rename(columns={'交易金额':'aft_bank_out_sum'})
    
    # 近3月总收入
    b4=df[(df['mon_dist']<=0) & (df['mon_dist']>=-3) & (df['交易类型']==0)][['id','交易金额']].copy()
    b4=b4.groupby('id',as_index=False).agg('sum')
    b4=b4.rename(columns={'交易金额':'aft_bank_inc_m3_sum'})
    
    # 近3月总支出
    b5=df[(df['mon_dist']<=0) & (df['mon_dist']>=-3) & (df['交易类型']==1)][['id','交易金额']].copy()
    b5=b5.groupby('id',as_index=False).agg('sum')
    b5=b5.rename(columns={'交易金额':'aft_bank_out_m3_sum'})   
    
    # 工资收入总额
    b6=df[(df['mon_dist']<=0) & (df['工资收入标记']==1)][['id','交易金额']].copy()
    b6=b6.groupby('id',as_index=False).agg('sum')
    b6=b6.rename(columns={'交易金额':'aft_bank_salary_sum'})    
    
    # 近3月收入笔数
    b7=df[(df['mon_dist']<=0) & (df['mon_dist']>=-3) & (df['交易类型']==0)][['id','交易金额']].copy()
    b7=b7.groupby('id',as_index=False).agg('count')
    b7=b7.rename(columns={'交易金额':'aft_bank_inc_m3_count'})

    # 近3月支出笔数
    b8=df[(df['mon_dist']<=0) & (df['mon_dist']>=-3) & (df['交易类型']==1)][['id','交易金额']].copy()
    b8=b8.groupby('id',as_index=False).agg('count')
    b8=b8.rename(columns={'交易金额':'aft_bank_out_m3_count'}) 
    
    # 近3月收入单次最大额
    b9=df[(df['mon_dist']<=0) & (df['mon_dist']>=-3) & (df['交易类型']==0)][['id','交易金额']].copy()
    b9=b9.groupby('id',as_index=False).agg('max')
    b9=b9.rename(columns={'交易金额':'aft_bank_inc_m3_max'}) 

    # 近3月收入单次最小额
    b10=df[(df['mon_dist']<=0) & (df['mon_dist']>=-3) & (df['交易类型']==0)][['id','交易金额']].copy()
    b10=b10.groupby('id',as_index=False).agg('min')
    b10=b10.rename(columns={'交易金额':'aft_bank_inc_m3_min'}) 
    
    # 近1月总收入
    b11=df[(df['mon_dist']>=-1) & (df['mon_dist']<=0) & (df['交易类型']==0)][['id','交易金额']].copy()
    b11=b11.groupby('id',as_index=False).agg('sum')
    b11=b11.rename(columns={'交易金额':'aft_bank_inc_m1_sum'})
    
    # 近1月总支出
    b12=df[(df['mon_dist']>=-1) & (df['mon_dist']<=0) & (df['交易类型']==1)][['id','交易金额']].copy()
    b12=b12.groupby('id',as_index=False).agg('sum')
    b12=b12.rename(columns={'交易金额':'aft_bank_out_m1_sum'}) 
        
    # 近3月收入方差
    b13=df[(df['mon_dist']>=-3) & (df['mon_dist']<=0)&(df['交易类型']==0)][['id','交易金额']].copy()
    b13=b13.groupby('id',as_index=False).agg('std')
    b13=b13.rename(columns={'交易金额':'aft_bank_inc_m3_std'})
    
    # 合并特征
    for i in [b2,b3,b4,b5,b6,b7,b8,b9,b10,b11,b12,b13]:
        fea_bank=pd.merge(fea_bank,i,how='left',on='id')
    
    # 近3月净收入
    fea_bank['aft_bank_ninc_m3_sum']=fea_bank['aft_bank_inc_m3_sum']-fea_bank['aft_bank_out_m3_sum']
    # 收入中工资占比
    fea_bank['aft_bank_salary_inc_rate']=fea_bank['aft_bank_salary_sum']/fea_bank['aft_bank_inc_sum']
    
    fea_bank=fea_bank.fillna(-1)
    
    
#     print('feature of aft bank detail',fea_bank.columns.tolist())
    return fea_bank

# %%
# 贷前浏览行为特征
def bef_browse(df,df_loan):
    df=pd.merge(df,df_loan,how='left',on='id')
    df=df[df['放款时间']>df['时间戳']]
    df['mon_dist']=(df['放款时间']-df['时间戳']).map(mon_distance)
    fea_browse = df[['id']].drop_duplicates().copy()
    
    # 浏览行为次数
    b1=df[['id']].copy()
    b1['bef_browse_bro_act_cnt']=1
    b1=b1.groupby('id').agg(sum).reset_index()
    
    # 浏览次数，按时间去重
    b2=df[['id','时间戳']].drop_duplicates().copy()
    b2=b2.groupby('id').agg('count').reset_index()
    b2=b2.rename(columns={'时间戳':'bef_browse_bro_cnt'})
    
    # 3个月内浏览子行为编号 
    b2=df[(df['mon_dist']<=3) & (df['mon_dist']>=0)][['id','浏览子行为编号']].copy()
    b2['num']=1
    b2=pd.pivot_table(b2,index='id',columns='浏览子行为编号',aggfunc='sum').reset_index()
    b2.columns=['bef_browse_浏览子行为编号_m3_'+str(i) for i in  b2.columns.droplevel()]
    b2=b2.rename(columns={'bef_browse_浏览子行为编号_m3_':'id'})
  
    # 所有浏览子行为编号 
    b3=df[['id','浏览子行为编号']].copy()
    b3['num']=1
    b3=pd.pivot_table(b3,index='id',columns='浏览子行为编号',aggfunc='sum').reset_index()
    b3.columns=['bef_browse_浏览子行为编号_'+str(i) for i in  b3.columns.droplevel()]
    b3=b3.rename(columns={'bef_browse_浏览子行为编号_':'id'})
    
    # 3个月内所有浏览行为编号
    b4=df[(df['mon_dist']<=3) & (df['mon_dist']>=0)][['id','浏览行为数据']].copy()
    b4['num']=1
    b4=pd.pivot_table(b4,index='id',columns='浏览行为数据',aggfunc='sum').reset_index()
    b4.columns=['bef_browse_浏览行为数据_m3_'+str(i) for i in b4.columns.droplevel()]
    b4=b4.rename(columns={'bef_browse_浏览行为数据_m3_':'id'})
    b4=b4[['id','bef_browse_浏览行为数据_m3_101','bef_browse_浏览行为数据_m3_110','bef_browse_浏览行为数据_m3_118','bef_browse_浏览行为数据_m3_164','bef_browse_浏览行为数据_m3_173','bef_browse_浏览行为数据_m3_189']]
    
    # 10天个内浏览子行为编号 
    b5=df[(df['时间戳']<=df['放款时间']) & (df['时间戳']>=df['放款时间']-10)][['id','浏览子行为编号']].copy()
    b5['num']=1
    b5=pd.pivot_table(b5,index='id',columns='浏览子行为编号',aggfunc='sum').reset_index()
    b5.columns=['bef_browse_浏览子行为编号_d10_'+str(i) for i in  b5.columns.droplevel()]
    b5=b5.rename(columns={'bef_browse_浏览子行为编号_d10_':'id'})    
    b5=b5[['id','bef_browse_浏览子行为编号_d10_1', 'bef_browse_浏览子行为编号_d10_3', 'bef_browse_浏览子行为编号_d10_4', 'bef_browse_浏览子行为编号_d10_5', 'bef_browse_浏览子行为编号_d10_6', 'bef_browse_浏览子行为编号_d10_7', 'bef_browse_浏览子行为编号_d10_8', 'bef_browse_浏览子行为编号_d10_9', 'bef_browse_浏览子行为编号_d10_10']]
    
    # 贷前浏览行为var
    b6=df[['id','浏览行为数据']].groupby('id',as_index=False)
    b6=b6['bef_browse_浏览行为数据'].agg({'bef_browse_浏览行为数据_var':'var'})
    
    for i in [b1,b2,b3,b4,b5,b6]:
        fea_browse=pd.merge(fea_browse,i,how='left',on='id')
    
    # test_set缺失此字段
    if  'bef_browse_浏览子行为编号_11' in fea_browse.columns:
        fea_browse=fea_browse.drop('bef_browse_浏览子行为编号_11',axis=1)
    if  'bef_browse_浏览子行为编号_m3_11' in fea_browse.columns:
        fea_browse=fea_browse.drop('bef_browse_浏览子行为编号_m3_11',axis=1)      
        
    fea_browse=fea_browse.fillna(-1)
#     print('feature of bef browse',fea_browse.columns.tolist())
    return fea_browse

# %%
# 贷后浏览行为特征
def aft_browse(df,df_loan):
    df=pd.merge(df,df_loan,how='left',on='id')
    df=df[df['放款时间']<=df['时间戳']]
    df['mon_dist']=(df['放款时间']-df['时间戳']).map(mon_distance)
    fea_browse = df[['id']].drop_duplicates().copy()
    
    # 浏览行为次数
    b1=df[['id']].copy()
    b1['aft_browse_bro_act_cnt']=1
    b1=b1.groupby('id').agg(sum).reset_index()
    
    # 浏览次数，按时间去重
    b2=df[['id','时间戳']].drop_duplicates().copy()
    b2=b2.groupby('id').agg('count').reset_index()
    b2=b2.rename(columns={'时间戳':'bef_browse_bro_cnt'})
    
    # 3个月内浏览子行为编号 
    b2=df[(df['mon_dist']<=0) & (df['mon_dist']>=-3)][['id','浏览子行为编号']].copy()
    b2['num']=1
    b2=pd.pivot_table(b2,index='id',columns='浏览子行为编号',aggfunc='sum').reset_index()
    b2.columns=['aft_browse_浏览子行为编号_m3_'+str(i) for i in  b2.columns.droplevel()]
    b2=b2.rename(columns={'aft_browse_浏览子行为编号_m3_':'id'})
    if 'aft_browse_浏览子行为编号_m3_2' in b2.columns:
        b2=b2.drop('aft_browse_浏览子行为编号_m3_2',axis=1)
    if 'aft_browse_浏览子行为编号_m3_11' in b2.columns:
        b2=b2.drop('aft_browse_浏览子行为编号_m3_11',axis=1)
        
  
    # 所有浏览子行为编号 
    b3=df[['id','浏览子行为编号']].copy()
    b3['num']=1
    b3=pd.pivot_table(b3,index='id',columns='浏览子行为编号',aggfunc='sum').reset_index()
    b3.columns=['aft_browse_浏览子行为编号_'+str(i) for i in  b3.columns.droplevel()]
    b3=b3.rename(columns={'aft_browse_浏览子行为编号_':'id'})
    if 'aft_browse_浏览子行为编号_2' in b3.columns:
        b3=b3.drop('aft_browse_浏览子行为编号_2',axis=1)
    if 'aft_browse_浏览子行为编号_11' in b3.columns:
        b3=b3.drop('aft_browse_浏览子行为编号_11',axis=1)
    
    # 3个月内所有浏览行为编号
    b4=df[(df['mon_dist']<=0) & (df['mon_dist']>=-3)][['id','浏览行为数据']].copy()
    b4['num']=1
    b4=pd.pivot_table(b4,index='id',columns='浏览行为数据',aggfunc='sum').reset_index()
    b4.columns=['aft_browse_浏览行为数据_m3_'+str(i) for i in b4.columns.droplevel()]
    b4=b4.rename(columns={'aft_browse_浏览行为数据_m3_':'id'})
    b4=b4[['id','aft_browse_浏览行为数据_m3_101','aft_browse_浏览行为数据_m3_110','aft_browse_浏览行为数据_m3_118','aft_browse_浏览行为数据_m3_164','aft_browse_浏览行为数据_m3_173','aft_browse_浏览行为数据_m3_189']]

    for i in [b1,b2,b3,b4]:
        fea_browse=pd.merge(fea_browse,i,how='left',on='id')
            
    fea_browse=fea_browse.fillna(-1)
#     print('feature of aft browse',fea_browse.columns.tolist())
    return fea_browse

# %%
# 贷前信用卡账单特征
def bef_bill(df,df_loan):
    df=pd.merge(df,df_loan,how='left',on='id',suffixes=['','_loan'])
    df=df[df['放款时间']>df['时间戳']]   
    df['mon_dist']=(df['放款时间']-df['时间戳']).map(mon_distance)
    fea_bill=df[['id']].drop_duplicates().copy()
    
    # 信用卡总银行数
    b1=df[['id','银行id']].drop_duplicates()[['id']].copy()
    b1['bef_bill_cre_bank_cnt']=1
    b1=b1.groupby('id').agg('sum').reset_index()
    
    # 信用卡在用的总银行数
    b2=df[df['上期账单金额']>0][['id','银行id']].drop_duplicates().copy()
    b2=b2.groupby('id').agg('count').reset_index()
    b2=b2.rename(columns={'银行id':'bef_bill_creused_bank_cnt'})
    
    # 信用卡在用的授信额度总和
    b3=df[df['上期账单金额']>0][['id','银行id','信用卡额度']].drop_duplicates().copy()
    b3=b3.drop('银行id',axis=1).groupby('id').agg('sum').reset_index()
    b3=b3.rename(columns={'信用卡额度':'bef_bill_creused_gramo_sum'})
    
    # 信用卡在用的单张最大授信额度
    b4=df[df['上期账单金额']>0][['id','信用卡额度']].copy()
    b4=b4.groupby('id').agg('max').reset_index()
    b4=b4.rename(columns={'信用卡额度':'bef_bill_creused_gramo_max'})
    
    # 信用卡在用的单张最小授信额度
    b5=df[df['上期账单金额']>0][['id','信用卡额度']].copy()
    b5=b5.groupby('id').agg('min').reset_index()
    b5=b5.rename(columns={'信用卡额度':'bef_bill_creused_gramo_min'})    
    
    # 信用卡消费笔数和
    b6=df[['id','消费笔数']].copy()
    b6=b6.groupby('id').agg('sum').reset_index()
    b6=b6.rename(columns={'消费笔数':'bef_bill_con_cnt'})
    
    # 信用卡消费笔数单月最大值
    b7=df[['id','消费笔数']].copy()
    b7=b7.groupby('id').agg('max').reset_index()
    b7=b7.rename(columns={'消费笔数':'bef_bill_con_max'})    
    
    # 循环利息和
    b8=df[['id','循环利息']].copy()
    b8=b8.groupby('id').agg('sum').reset_index()
    b8=b8.rename(columns={'循环利息':'bef_bill_inter_sum'})
    
    # 循环利息最大额
    b9=df[['id','循环利息']].copy()
    b9=b9.groupby('id').agg('max').reset_index()
    b9=b9.rename(columns={'循环利息':'bef_bill_inter_max'})    
    
    # 循环利息次数
    b10=df[df['循环利息']>0][['id']].copy()
    b10['bef_bill_inter_cnt']=1
    b10=b10.groupby('id').agg(sum).reset_index()
    
    # 可用金额和
    b11=df[['id','可用金额']].copy()
    b11=b11.groupby('id').agg('sum').reset_index()
    b11=b11.rename(columns={'可用金额':'bef_bill_amo_ava'})
    
    # 每期账单上期未还款次数和
    b12=df[(df['上期账单金额']>0) & (df['上期还款金额']==0)][['id']].copy()
    b12['bef_bill_ovdu_cnt']=1
    b12=b12.groupby('id').agg('sum').reset_index()
    
    # 每期账单上期未结清次数和
    b13=df[(df['上期账单金额']>df['上期还款金额']) & (df['上期还款金额']>0)][['id']].copy()
    b13['bef_bill_unc_cnt']=1
    b13=b13.groupby('id').agg('sum').reset_index()
    
    # 还款状态
    b14=df[['id','还款状态']].copy()
    b14=b14.groupby('id').agg('sum').reset_index()
    b14=b14.rename(columns={'还款状态':'bef_bill_payst_cnt'})
    
    # 近3月预借现金额度
    b15=df[(df['mon_dist']<=3) & (df['mon_dist']>=0)][['id','预借现金额度']].copy()
    b15=b15.groupby('id').agg('sum').reset_index()
    b15=b15.rename(columns={'预借现金额度':'bef_bill_preloan_m3_sum'})
    
    # 近3月预借现金次数
    b16=df[(df['mon_dist']<=3) & (df['mon_dist']>=0)][['id','预借现金额度']].copy()
    b16= b16.groupby('id').agg('count').reset_index()
    b16=b16.rename(columns={'预借现金额度':'bef_bill_preloan_m3_cnt'})
    
    # 近3月预借现金银行数
    b17=df[(df['mon_dist']<=3) & (df['mon_dist']>=0) &(df['预借现金额度']>0)][['id','银行id']].drop_duplicates().copy()
    b17=b17.groupby('id').agg('count').reset_index()
    b17=b17.rename(columns={'银行id':'bef_bill_preloan_bank_cnt'})
    
    # 信用卡当前使用额度
    b18=df[['id','时间戳','银行id','本期账单余额']].copy()
    b18=b18.loc[df.groupby(['id','银行id']).apply(lambda x: x['时间戳'].idxmax())].reset_index()
    b18=b18.pivot_table(index='id',values='本期账单余额',aggfunc='sum').reset_index()
    b18=b18.rename(columns={'本期账单余额':'bef_bill_creamo_used'})
    
    # 近3月每期账单上期未还款次数和
    b19=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['mon_dist']<=3) & (df['mon_dist']>=0)][['id']].copy()
    b19['bef_bill_ovdu_m3_cnt']=1
    b19=b19.groupby('id').agg('sum').reset_index()
    
    # 近3月每期账单上期未结清次数和
    b20=df[(df['上期账单金额']>df['上期还款金额']) & (df['上期还款金额']>0)&(df['mon_dist']<=3) & (df['mon_dist']>=0)][['id']].copy()
    b20['bef_bill_unc_m3_cnt']=1
    b20=b20.groupby('id').agg('sum').reset_index()
    
    # 老段子特征1
    b21=df[df['时间戳']<=df['放款时间']][['id','银行id']].groupby('id',as_index=False).agg('count')
    b21=b21.rename(columns={'银行id':'bef_bill_t0'})
    
    # 老段子特征2
    b22=df[df['时间戳']<=df['放款时间']-1][['id','银行id']].groupby('id',as_index=False).agg('count')
    b22=b22.rename(columns={'银行id':'bef_bill_t1'})
    
    # 老段子特征3
    b23=df[df['时间戳']<=df['放款时间']-2][['id','银行id']].groupby('id',as_index=False).agg('count')
    b23=b23.rename(columns={'银行id':'bef_bill_t2'})
    
    # 近3月信用卡本期账单余额方差
    b24=df[(df['mon_dist']<=3) & (df['mon_dist']>=0)][['id','本期账单余额']].copy()
    b24=b24.groupby('id',as_index=False).agg('std')
    b24=b24.rename(columns={'本期账单余额':'bef_bill_amo_std'})
    
    for i in [b1,b2,b3,b4,b5,b6,b7,b7,b9,b10,b11,b12,b13,b14,b15,b16,b17,b18,b19,b20,b21,b22,b23,b24]:
        fea_bill=pd.merge(fea_bill,i,how='left',on='id')
    
    fea_bill['bef_bill_preloan_bank_rate']=fea_bill['bef_bill_cre_bank_cnt']/fea_bill['bef_bill_preloan_bank_cnt']
    fea_bill['bef_bill_creamo_use_rate']=(fea_bill['bef_bill_creamo_used']/fea_bill['bef_bill_creused_gramo_sum'])
    fea_bill.loc[np.isinf(fea_bill['bef_bill_creamo_use_rate']),'bef_bill_creamo_use_rate']=0
    
    fea_bill=fea_bill.fillna(-1)
        
#     print('feature of bef bill',fea_bill.columns.tolist())    
    
    return fea_bill

# %%
# 贷后信用卡账单特征
def aft_bill(df,df_loan):
    df=pd.merge(df,df_loan,how='left',on='id',suffixes=['','_loan'])
    df=df[df['放款时间']<=df['时间戳']]   
    df['mon_dist']=(df['放款时间']-df['时间戳']).map(mon_distance)
    fea_bill=df[['id']].drop_duplicates().copy()
    
    # 信用卡总银行数
    b1=df[['id','银行id']].drop_duplicates()[['id']].copy()
    b1['aft_bill_cre_bank_cnt']=1
    b1=b1.groupby('id').agg('sum').reset_index()
    
    # 信用卡在用的总银行数
    b2=df[df['上期账单金额']>0][['id','银行id']].drop_duplicates().copy()
    b2=b2.groupby('id').agg('count').reset_index()
    b2=b2.rename(columns={'银行id':'aft_bill_creused_bank_cnt'})
    
    # 信用卡在用的授信额度总和
    b3=df[df['上期账单金额']>0][['id','银行id','信用卡额度']].drop_duplicates().copy()
    b3=b3.drop('银行id',axis=1).groupby('id').agg('sum').reset_index()
    b3=b3.rename(columns={'信用卡额度':'aft_bill_creused_gramo_sum'})
    
    # 信用卡在用的单张最大授信额度
    b4=df[df['上期账单金额']>0][['id','信用卡额度']].copy()
    b4=b4.groupby('id').agg('max').reset_index()
    b4=b4.rename(columns={'信用卡额度':'aft_bill_creused_gramo_max'})
    
    # 信用卡在用的单张最小授信额度
    b5=df[df['上期账单金额']>0][['id','信用卡额度']].copy()
    b5=b5.groupby('id').agg('min').reset_index()
    b5=b5.rename(columns={'信用卡额度':'aft_bill_creused_gramo_min'})    
    
    # 信用卡消费笔数和
    b6=df[['id','消费笔数']].copy()
    b6=b6.groupby('id').agg('sum').reset_index()
    b6=b6.rename(columns={'消费笔数':'aft_bill_con_cnt'})
    
    # 信用卡消费笔数单月最大值
    b7=df[['id','消费笔数']].copy()
    b7=b7.groupby('id').agg('max').reset_index()
    b7=b7.rename(columns={'消费笔数':'aft_bill_con_max'})    
    
    # 循环利息和
    b8=df[['id','循环利息']].copy()
    b8=b8.groupby('id').agg('sum').reset_index()
    b8=b8.rename(columns={'循环利息':'aft_bill_inter_sum'})
    
    # 循环利息最大额
    b9=df[['id','循环利息']].copy()
    b9=b9.groupby('id').agg('max').reset_index()
    b9=b9.rename(columns={'循环利息':'aft_bill_inter_max'})    
    
    # 循环利息次数
    b10=df[df['循环利息']>0][['id']].copy()
    b10['aft_bill_inter_cnt']=1
    b10=b10.groupby('id').agg(sum).reset_index()
    
    # 可用金额和
    b11=df[['id','可用金额']].copy()
    b11=b11.groupby('id').agg('sum').reset_index()
    b11=b11.rename(columns={'可用金额':'aft_bill_amo_ava'})
    
    # 每期账单上期未还款次数和
    b12=df[(df['上期账单金额']>0) & (df['上期还款金额']==0)][['id']].copy()
    b12['aft_bill_ovdu_cnt']=1
    b12=b12.groupby('id').agg('sum').reset_index()
    
    # 每期账单上期未结清次数和
    b13=df[(df['上期账单金额']>df['上期还款金额']) & (df['上期还款金额']>0)][['id']].copy()
    b13['aft_bill_unc_cnt']=1
    b13=b13.groupby('id').agg('sum').reset_index()
    
    # 还款状态
    b14=df[['id','还款状态']].copy()
    b14=b14.groupby('id').agg('sum').reset_index()
    b14=b14.rename(columns={'还款状态':'aft_bill_payst_cnt'})
    
    # 近3月预借现金额度
    b15=df[(df['mon_dist']<=0) & (df['mon_dist']>=-3)][['id','预借现金额度']].copy()
    b15=b15.groupby('id').agg('sum').reset_index()
    b15=b15.rename(columns={'预借现金额度':'aft_bill_preloan_m3_sum'})
    
    # 近3月预借现金次数
    b16=df[(df['mon_dist']<=0) & (df['mon_dist']>=-3)][['id','预借现金额度']].copy()
    b16= b16.groupby('id').agg('count').reset_index()
    b16=b16.rename(columns={'预借现金额度':'aft_bill_preloan_m3_cnt'})
    
    # 近3月预借现金银行数
    b17=df[(df['mon_dist']<=0) & (df['mon_dist']>=-3) &(df['预借现金额度']>0)][['id','银行id']].drop_duplicates().copy()
    b17=b17.groupby('id').agg('count').reset_index()
    b17=b17.rename(columns={'银行id':'aft_bill_preloan_bank_cnt'})
    
    # 信用卡当前使用额度
    b18=df[['id','时间戳','银行id','本期账单余额']].copy()
    b18=b18.loc[df.groupby(['id','银行id']).apply(lambda x: x['时间戳'].idxmax())].reset_index()
    b18=b18.pivot_table(index='id',values='本期账单余额',aggfunc='sum').reset_index()
    b18=b18.rename(columns={'本期账单余额':'aft_bill_creamo_used'})
    
    # 近3月每期账单上期未还款次数和
    b19=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['mon_dist']<=3) & (df['mon_dist']>=0)][['id']].copy()
    b19['aft_bill_ovdu_m3_cnt']=1
    b19=b19.groupby('id').agg('sum').reset_index()
    
    # 近3月每期账单上期未结清次数和
    b20=df[(df['上期账单金额']>df['上期还款金额']) & (df['上期还款金额']>0)&(df['mon_dist']<=3) & (df['mon_dist']>=0)][['id']].copy()
    b20['aft_bill_unc_m3_cnt']=1
    b20=b20.groupby('id').agg('sum').reset_index()
    
    # 老段子特征1
    b21=df[df['时间戳']>=df['放款时间']][['id','银行id']].groupby('id',as_index=False).agg('count')
    b21=b21.rename(columns={'银行id':'aft_bill_t0'})
    
    # 老段子特征2
    b22=df[df['时间戳']>=df['放款时间']+1][['id','银行id']].groupby('id',as_index=False).agg('count')
    b22=b22.rename(columns={'银行id':'aft_bill_t1'})
    
    # 老段子特征3
    b23=df[df['时间戳']>=df['放款时间']+2][['id','银行id']].groupby('id',as_index=False).agg('count')
    b23=b23.rename(columns={'银行id':'aft_bill_t2'})
    
    # 老段子特征4
    b24=df[df['时间戳']>=df['放款时间']+10][['id','银行id']].groupby('id',as_index=False).agg('count')
    b24=b24.rename(columns={'银行id':'aft_bill_t10'})    
    
    # 老段子特征5
    b25=df[df['时间戳']>=df['放款时间']+20][['id','银行id']].groupby('id',as_index=False).agg('count')
    b25=b25.rename(columns={'银行id':'aft_bill_t20'})    
    
    # 老段子特征6
    b26=df[df['时间戳']>=df['放款时间']+30][['id','银行id']].groupby('id',as_index=False).agg('count')
    b26=b26.rename(columns={'银行id':'aft_bill_t30'})    
    
    # 近3月信用卡本期账单余额方差
    b27=df[(df['mon_dist']<=0) & (df['mon_dist']>=-3)][['id','本期账单余额']].copy()
    b27=b27.groupby('id',as_index=False).agg('std')
    b27=b27.rename(columns={'本期账单余额':'aft_bill_amo_std'})
    
    # 0天后预借现金额度
    b28=df[(df['时间戳']>=df['放款时间'])][['id','预借现金额度']].copy()
    b28=b28.groupby('id').agg('sum').reset_index()
    b28=b28.rename(columns={'预借现金额度':'aft_bill_preloan_d0_sum'})    
    
    # 1天后预借现金额度
    b29=df[(df['时间戳']>=df['放款时间']+1)][['id','预借现金额度']].copy()
    b29=b29.groupby('id').agg('sum').reset_index()
    b29=b29.rename(columns={'预借现金额度':'aft_bill_preloan_d1_sum'}) 
    
    # 2天后预借现金额度
    b30=df[(df['时间戳']>=df['放款时间']+2)][['id','预借现金额度']].copy()
    b30=b30.groupby('id').agg('sum').reset_index()
    b30=b30.rename(columns={'预借现金额度':'aft_bill_preloan_d2_sum'}) 
    
    # 10天后预借现金额度
    b31=df[(df['时间戳']>=df['放款时间']+10)][['id','预借现金额度']].copy()
    b31=b31.groupby('id').agg('sum').reset_index()
    b31=b31.rename(columns={'预借现金额度':'aft_bill_preloan_d10_sum'}) 
    
    # 20天后预借现金额度
    b32=df[(df['时间戳']>=df['放款时间']+20)][['id','预借现金额度']].copy()
    b32=b32.groupby('id').agg('sum').reset_index()
    b32=b32.rename(columns={'预借现金额度':'aft_bill_preloan_d20_sum'})
    
    # 30天后预借现金额度
    b33=df[(df['时间戳']>=df['放款时间']+30)][['id','预借现金额度']].copy()
    b33=b33.groupby('id').agg('sum').reset_index()
    b33=b33.rename(columns={'预借现金额度':'aft_bill_preloan_d30_sum'}) 
    
    # 0天后每期账单上期未还款金额和
    b34=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['时间戳']>=df['放款时间']+0)][['id','上期账单金额']].copy()
    b34=b34.groupby('id',as_index=False).agg('sum')
    b34=b34.rename(columns={'上期账单金额':'aft_bill_ovdu_d0_sum'})
    
    # 1天后每期账单上期未还款金额和
    b35=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['时间戳']>=df['放款时间']+1)][['id','上期账单金额']].copy()
    b35=b35.groupby('id',as_index=False).agg('sum')
    b35=b35.rename(columns={'上期账单金额':'aft_bill_ovdu_d1_sum'})    
    
    # 2天后每期账单上期未还款金额和
    b36=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['时间戳']>=df['放款时间']+2)][['id','上期账单金额']].copy()
    b36=b36.groupby('id',as_index=False).agg('sum')
    b36=b36.rename(columns={'上期账单金额':'aft_bill_ovdu_d2_sum'})    
    
    # 10天后每期账单上期未还款金额和
    b37=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['时间戳']>=df['放款时间']+10)][['id','上期账单金额']].copy()
    b37=b37.groupby('id',as_index=False).agg('sum')
    b37=b37.rename(columns={'上期账单金额':'aft_bill_ovdu_d10_sum'})    
    
    # 20天后每期账单上期未还款金额和
    b38=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['时间戳']>=df['放款时间']+20)][['id','上期账单金额']].copy()
    b38=b38.groupby('id',as_index=False).agg('sum')
    b38=b38.rename(columns={'上期账单金额':'aft_bill_ovdu_d20_sum'})    
    
    # 30天后每期账单上期未还款金额和
    b39=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['时间戳']>=df['放款时间']+30)][['id','上期账单金额']].copy()
    b39=b39.groupby('id',as_index=False).agg('sum')
    b39=b39.rename(columns={'上期账单金额':'aft_bill_ovdu_d30_sum'})    
    
    # 0天后信用卡总银行数
    b40=df[(df['时间戳']>=df['放款时间']+0)][['id','银行id']].drop_duplicates()[['id']].copy()
    b40['aft_bill_cre_bank_d0_cnt']=1
    b40=b40.groupby('id').agg('sum').reset_index() 
    
    # 10天后信用卡总银行数
    b41=df[(df['时间戳']>=df['放款时间']+10)][['id','银行id']].drop_duplicates()[['id']].copy()
    b41['aft_bill_cre_bank_d10_cnt']=1
    b41=b41.groupby('id').agg('sum').reset_index()
    
    # 30天后信用卡总银行数
    b42=df[(df['时间戳']>=df['放款时间']+30)][['id','银行id']].drop_duplicates()[['id']].copy()
    b42['aft_bill_cre_bank_d30_cnt']=1
    b42=b42.groupby('id').agg('sum').reset_index()
    
    # 0天后每期账单上期未还款金额次数
    b43=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['时间戳']>=df['放款时间']+0)][['id','上期账单金额']].copy()
    b43=b43.groupby('id',as_index=False).agg('count')
    b43=b43.rename(columns={'上期账单金额':'aft_bill_ovdu_d0_count'})
    
    # 1天后每期账单上期未还款金额和
    b44=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['时间戳']>=df['放款时间']+1)][['id','上期账单金额']].copy()
    b44=b44.groupby('id',as_index=False).agg('count')
    b44=b44.rename(columns={'上期账单金额':'aft_bill_ovdu_d1_count'})    
    
    # 2天后每期账单上期未还款金额和
    b45=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['时间戳']>=df['放款时间']+2)][['id','上期账单金额']].copy()
    b45=b45.groupby('id',as_index=False).agg('count')
    b45=b45.rename(columns={'上期账单金额':'aft_bill_ovdu_d2_count'})    
    
    # 10天后每期账单上期未还款金额和
    b46=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['时间戳']>=df['放款时间']+10)][['id','上期账单金额']].copy()
    b46=b46.groupby('id',as_index=False).agg('count')
    b46=b46.rename(columns={'上期账单金额':'aft_bill_ovdu_d10_count'})    
    
    # 20天后每期账单上期未还款金额和
    b47=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['时间戳']>=df['放款时间']+20)][['id','上期账单金额']].copy()
    b47=b47.groupby('id',as_index=False).agg('count')
    b47=b47.rename(columns={'上期账单金额':'aft_bill_ovdu_d20_count'})    
    
    # 30天后每期账单上期未还款金额和
    b48=df[(df['上期账单金额']>0) & (df['上期还款金额']==0) &(df['时间戳']>=df['放款时间']+30)][['id','上期账单金额']].copy()
    b48=b48.groupby('id',as_index=False).agg('count')
    b48=b48.rename(columns={'上期账单金额':'aft_bill_ovdu_d30_count'})    
    
   
    for i in [b1,b2,b3,b4,b5,b6,b7,b8,b9,b10,b11,b12,b13,b14,b15,b16,b17,b18,b19,b20,b21,b22,b23,b24,b25,b26,b27,b28,b29,b30,b31,b32,b33,b34,b35,b36,b37,b38,b39,b40,b41,b42,b43,b44,b45,b46,b47,b48]:
        fea_bill=pd.merge(fea_bill,i,how='left',on='id')
        
    fea_bill['aft_bill_preloan_bank_rate']=fea_bill['aft_bill_cre_bank_cnt']/fea_bill['aft_bill_preloan_bank_cnt']
    fea_bill['aft_bill_creamo_use_rate']=fea_bill['aft_bill_creamo_used']/fea_bill['aft_bill_creused_gramo_sum']
    fea_bill.loc[np.isinf(fea_bill['aft_bill_creamo_use_rate']),'aft_bill_creamo_use_rate']=0
    fea_bill['aft_bill_cre_bank_add']=fea_bill['aft_bill_cre_bank_d30_cnt']/fea_bill['aft_bill_cre_bank_d0_cnt']
    
    
    fea_bill=fea_bill.fillna(-1)
        
#     print('feature of aft bill',fea_bill.columns.tolist())    
    
    return fea_bill

# %%
fea_user=user(tr_user)
fea_user.to_csv('data/feature_data/fea_user.csv')
feat_user=user(te_user)
feat_user.to_csv('data/feature_data/feat_user.csv')

# %%
fea_bef_bank=bef_bank(tr_bank,tr_loan)
fea_bef_bank.to_csv('data/feature_data/fea_bef_bank.csv')
feat_bef_bank=bef_bank(te_bank,te_loan)
feat_bef_bank.to_csv('data/feature_data/feat_bef_bank.csv')

# %%
fea_aft_bank=aft_bank(tr_bank,tr_loan)
fea_aft_bank.to_csv('data/feature_data/fea_aft_bank.csv')
feat_aft_bank=aft_bank(te_bank,te_loan)
feat_aft_bank.to_csv('data/feature_data/feat_aft_bank.csv')

# %%
fea_bef_browse=bef_browse(tr_browse,tr_loan)
fea_bef_browse.to_csv('data/feature_data/fea_bef_browse.csv')
feat_bef_browse=bef_browse(te_browse,te_loan)
feat_bef_browse.to_csv('data/feature_data/feat_bef_browse.csv')
# Out:
#    id   浏览行为数据_var
# 0   2  3390.796753
# 1   3  2536.790245
# 2   4  2942.068840
# 3   6     0.000000
# 4   7  3021.163081
#       id   浏览行为数据_var
# 0  55597  2503.160574
# 1  55598  3573.716033
# 2  55601  3050.158869
# 3  55602  2929.986097
# 4  55603  3278.076146

# %%
fea_aft_browse=aft_browse(tr_browse,tr_loan)
fea_aft_browse.to_csv('data/feature_data/fea_aft_browse.csv')
feat_aft_browse=aft_browse(te_browse,te_loan)
feat_aft_browse.to_csv('data/feature_data/feat_aft_browse.csv')

# %%
fea_bef_bill=bef_bill(tr_bill,tr_loan)
fea_bef_bill.to_csv('data/feature_data/fea_bef_bill.csv')
feat_bef_bill=bef_bill(te_bill,te_loan)
feat_bef_bill.to_csv('data/feature_data/feat_bef_bill.csv')

# %%
fea_aft_bill=aft_bill(tr_bill,tr_loan)
fea_aft_bill.to_csv('data/feature_data/fea_aft_bill.csv')
feat_aft_bill=aft_bill(te_bill,te_loan)
feat_aft_bill.to_csv('data/feature_data/feat_aft_bill.csv')

# %%
train_set=tr_overdue.merge(fea_user,on='id',how='left').copy()
train_set=train_set.merge(fea_bef_bank,on='id',how='left')
train_set=train_set.merge(fea_bef_browse,on='id',how='left')
train_set=train_set.merge(fea_bef_bill,on='id',how='left')
train_set=train_set.merge(fea_aft_bank,on='id',how='left')
train_set=train_set.merge(fea_aft_browse,on='id',how='left')
train_set=train_set.merge(fea_aft_bill,on='id',how='left')

train_set=train_set.fillna(-1)

test_set=te_id.merge(feat_user,on='id',how='left').copy()
test_set=test_set.merge(feat_bef_bank,on='id',how='left')
test_set=test_set.merge(feat_bef_browse,on='id',how='left')
test_set=test_set.merge(feat_bef_bill,on='id',how='left')
test_set=test_set.merge(feat_aft_bank,on='id',how='left')
test_set=test_set.merge(feat_aft_browse,on='id',how='left')
test_set=test_set.merge(feat_aft_bill,on='id',how='left')

test_set=test_set.fillna(-1)

print('训练集大小',train_set.shape)
print('测试集大小',test_set.shape)
print('feature_list')
print(train_set.columns.tolist()[2:])
# Out:
# 训练集大小 (55596, 194)
# 测试集大小 (13899, 193)
# feature_list
# ['性别_0', '性别_1', '性别_2', '职业_0', '职业_1', '职业_2', '职业_3', '职业_4', '教育程度_0', '教育程度_1', '教育程度_2', '教育程度_3', '教育程度_4', '婚姻状态_0', '婚姻状态_1', '婚姻状态_2', '婚姻状态_3', '婚姻状态_4', '婚姻状态_5', '户口类型_0', '户口类型_1', '户口类型_2', '户口类型_3', '户口类型_4', 'bef_bank_salary_ave', 'bef_bank_inc_sum', 'bef_bank_out_sum', 'bef_bank_inc_m3_sum', 'bef_bank_out_m3_sum', 'bef_bank_salary_sum', 'bef_bank_inc_m3_count', 'bef_bank_out_m3_count', 'bef_bank_inc_m3_max', 'bef_bank_inc_m3_min', 'bef_bank_inc_m1_sum', 'bef_bank_out_m1_sum', 'bef_bank_inc_m3_std', 'bef_bank_ninc_m3_sum', 'bef_bank_salary_inc_rate', 'bef_browse_bro_act_cnt', 'bef_browse_浏览子行为编号_m3_1', 'bef_browse_浏览子行为编号_m3_2', 'bef_browse_浏览子行为编号_m3_3', 'bef_browse_浏览子行为编号_m3_4', 'bef_browse_浏览子行为编号_m3_5', 'bef_browse_浏览子行为编号_m3_6', 'bef_browse_浏览子行为编号_m3_7', 'bef_browse_浏览子行为编号_m3_8', 'bef_browse_浏览子行为编号_m3_9', 'bef_browse_浏览子行为编号_m3_10', 'bef_browse_浏览子行为编号_1', 'bef_browse_浏览子行为编号_2', 'bef_browse_浏览子行为编号_3', 'bef_browse_浏览子行为编号_4', 'bef_browse_浏览子行为编号_5', 'bef_browse_浏览子行为编号_6', 'bef_browse_浏览子行为编号_7', 'bef_browse_浏览子行为编号_8', 'bef_browse_浏览子行为编号_9', 'bef_browse_浏览子行为编号_10', 'bef_browse_浏览行为数据_m3_101', 'bef_browse_浏览行为数据_m3_110', 'bef_browse_浏览行为数据_m3_118', 'bef_browse_浏览行为数据_m3_164', 'bef_browse_浏览行为数据_m3_173', 'bef_browse_浏览行为数据_m3_189', 'bef_browse_浏览子行为编号_d10_1', 'bef_browse_浏览子行为编号_d10_3', 'bef_browse_浏览子行为编号_d10_4', 'bef_browse_浏览子行为编号_d10_5', 'bef_browse_浏览子行为编号_d10_6', 'bef_browse_浏览子行为编号_d10_7', 'bef_browse_浏览子行为编号_d10_8', 'bef_browse_浏览子行为编号_d10_9', 'bef_browse_浏览子行为编号_d10_10', '浏览行为数据_var', 'bef_bill_cre_bank_cnt', 'bef_bill_creused_bank_cnt', 'bef_bill_creused_gramo_sum', 'bef_bill_creused_gramo_max', 'bef_bill_creused_gramo_min', 'bef_bill_con_cnt', 'bef_bill_con_max_x', 'bef_bill_con_max_y', 'bef_bill_inter_max', 'bef_bill_inter_cnt', 'bef_bill_amo_ava', 'bef_bill_ovdu_cnt', 'bef_bill_unc_cnt', 'bef_bill_payst_cnt', 'bef_bill_preloan_m3_sum', 'bef_bill_preloan_m3_cnt', 'bef_bill_preloan_bank_cnt', 'bef_bill_creamo_used', 'bef_bill_ovdu_m3_cnt', 'bef_bill_unc_m3_cnt', 'bef_bill_t0', 'bef_bill_t1', 'bef_bill_t2', 'bef_bill_amo_std', 'bef_bill_preloan_bank_rate', 'bef_bill_creamo_use_rate', 'aft_bank_inc_sum', 'aft_bank_out_sum', 'aft_bank_inc_m3_sum', 'aft_bank_out_m3_sum', 'aft_bank_salary_sum', 'aft_bank_inc_m3_count', 'aft_bank_out_m3_count', 'aft_bank_inc_m3_max', 'aft_bank_inc_m3_min', 'aft_bank_inc_m1_sum', 'aft_bank_out_m1_sum', 'aft_bank_inc_m3_std', 'aft_bank_ninc_m3_sum', 'aft_bank_salary_inc_rate', 'aft_browse_bro_act_cnt', 'aft_browse_浏览子行为编号_m3_1', 'aft_browse_浏览子行为编号_m3_3', 'aft_browse_浏览子行为编号_m3_4', 'aft_browse_浏览子行为编号_m3_5', 'aft_browse_浏览子行为编号_m3_6', 'aft_browse_浏览子行为编号_m3_7', 'aft_browse_浏览子行为编号_m3_8', 'aft_browse_浏览子行为编号_m3_9', 'aft_browse_浏览子行为编号_m3_10', 'aft_browse_浏览子行为编号_1', 'aft_browse_浏览子行为编号_3', 'aft_browse_浏览子行为编号_4', 'aft_browse_浏览子行为编号_5', 'aft_browse_浏览子行为编号_6', 'aft_browse_浏览子行为编号_7', 'aft_browse_浏览子行为编号_8', 'aft_browse_浏览子行为编号_9', 'aft_browse_浏览子行为编号_10', 'aft_browse_浏览行为数据_m3_101', 'aft_browse_浏览行为数据_m3_110', 'aft_browse_浏览行为数据_m3_118', 'aft_browse_浏览行为数据_m3_164', 'aft_browse_浏览行为数据_m3_173', 'aft_browse_浏览行为数据_m3_189', 'aft_bill_cre_bank_cnt', 'aft_bill_creused_bank_cnt', 'aft_bill_creused_gramo_sum', 'aft_bill_creused_gramo_max', 'aft_bill_creused_gramo_min', 'aft_bill_con_cnt', 'aft_bill_con_max', 'aft_bill_inter_sum', 'aft_bill_inter_max', 'aft_bill_inter_cnt', 'aft_bill_amo_ava', 'aft_bill_ovdu_cnt', 'aft_bill_unc_cnt', 'aft_bill_payst_cnt', 'aft_bill_preloan_m3_sum', 'aft_bill_preloan_m3_cnt', 'aft_bill_preloan_bank_cnt', 'aft_bill_creamo_used', 'aft_bill_ovdu_m3_cnt', 'aft_bill_unc_m3_cnt', 'aft_bill_t0', 'aft_bill_t1', 'aft_bill_t2', 'aft_bill_t10', 'aft_bill_t20', 'aft_bill_t30', 'aft_bill_amo_std', 'aft_bill_preloan_d0_sum', 'aft_bill_preloan_d1_sum', 'aft_bill_preloan_d2_sum', 'aft_bill_preloan_d10_sum', 'aft_bill_preloan_d20_sum', 'aft_bill_preloan_d30_sum', 'aft_bill_ovdu_d0_sum', 'aft_bill_ovdu_d1_sum', 'aft_bill_ovdu_d2_sum', 'aft_bill_ovdu_d10_sum' ...

# %%
# 此步跳过，数据归一化处理会过拟合
fea_list=train_set.columns.tolist()[2:]
scaler1 = MinMaxScaler()
train_set[fea_list]=scaler1.fit_transform(train_set[fea_list])
scaler2 = MinMaxScaler()
test_set[fea_list]=scaler2.fit_transform(test_set[fea_list])

# %%
# 拆分训练集和验证集
trainsub,validsub=train_test_split(train_set,test_size = 0.2, stratify = train_set['label'], random_state=100)

# 模型输入特征
trainsub_dm=xgb.DMatrix(trainsub.drop(['id','label'],axis=1),label=trainsub[['label']])
validsub_dm=xgb.DMatrix(validsub.drop(['id','label'],axis=1),label=validsub[['label']])
test_dm=xgb.DMatrix(test_set.drop(['id'],axis=1))

# 模型1训练调参
params= {'booster': 'gbtree', 'objective': 'binary:logistic',
         'eval_metric': 'error', 'gamma': 2,'min_child_weight': 1.1,
         'max_depth': 5, 'lambda': 20, 'subsample': 0.8, 'colsample_bytree': 0.7,
         'colsample_bylevel': 0.7, 'eta': 0.01, 'tree_method': 'exact', 
         'seed': 0, 'nthread': 12,'early_stop':100,'scale_pos_weight':7}
watchlist = [(trainsub_dm, 'train'),(validsub_dm, 'val')]
boost_round=2000
model=xgb.train(params,trainsub_dm,num_boost_round=boost_round,evals=watchlist,early_stopping_rounds=2000)

# 模型2训练调参
# params={'booster':'gbtree','objective': 'rank:pairwise','eval_metric':'auc','gamma':0.1,'min_child_weight':1.1,
#     'max_depth':7,'lambda':10,'subsample':0.7,'colsample_bytree':0.7,'colsample_bylevel':0.7,'eta': 0.01,
#     'tree_method':'exact','seed':1000,'nthread':12}
# watchlist = [(trainsub_dm, 'train'),(validsub_dm, 'val')]
# model = xgb.train(params, trainsub_dm,num_boost_round=2000,evals=watchlist,early_stopping_rounds=500)

# 训练集ks值
df_ks=trainsub[['label']].copy()
df_ks['pred']=model.predict(trainsub_dm)
tr_ks,tr_auc=plot_ks_curve(df_ks)

# 验证集ks值
vres=validsub[['label']].copy()
vres['pred']=model.predict(validsub_dm)
# vres.loc[vres['pred']>1,'pred']=1
# vres.loc[vres['pred']<0,'pred']=0
te_ks,te_auc=plot_ks_curve(vres)

para_txt_path='data/para.txt'
with open(para_txt_path,'a') as f:
    params['num_boost_round']=boost_round
    f.write(str(params)+'\n')
    f.write('train_ks_value:'+str(tr_ks)+', train_auc_value:'+str(tr_auc)+'\n')
    f.write('valid_ks_value:'+str(te_ks)+', valid_auc_value:'+str(te_auc)+'\n')
f.close()
# Out:
# [0]	train-error:0.33056	val-error:0.339748
# Multiple eval metrics have been passed: 'val-error' will be used for early stopping.
#
# Will train until val-error hasn't improved in 2000 rounds.
# [1]	train-error:0.324512	val-error:0.333723
# [2]	train-error:0.321477	val-error:0.331205
# [3]	train-error:0.325029	val-error:0.335432
# [4]	train-error:0.322668	val-error:0.331745
# [5]	train-error:0.322736	val-error:0.331565
# [6]	train-error:0.320645	val-error:0.330126
# [7]	train-error:0.320375	val-error:0.329766
# [8]	train-error:0.321342	val-error:0.330036
# [9]	train-error:0.321005	val-error:0.329496
# [10]	train-error:0.322084	val-error:0.330396
# [11]	train-error:0.321499	val-error:0.329766
# [12]	train-error:0.321207	val-error:0.329406
# [13]	train-error:0.321567	val-error:0.329856
# [14]	train-error:0.321477	val-error:0.330306
# [15]	train-error:0.321589	val-error:0.330576
# [16]	train-error:0.321837	val-error:0.330396
# [17]	train-error:0.322196	val-error:0.330755
# [18]	train-error:0.322601	val-error:0.330665
# [19]	train-error:0.321837	val-error:0.331295
# [20]	train-error:0.321971	val-error:0.330396
# [21]	train-error:0.321859	val-error:0.330935
# [22]	train-error:0.321117	val-error:0.330396
# [23]	train-error:0.320757	val-error:0.329676
# [24]	train-error:0.321005	val-error:0.329586
# [25]	train-error:0.321522	val-error:0.330486
# [26]	train-error:0.322196	val-error:0.330576
# [27]	train-error:0.321881	val-error:0.329946
# [28]	train-error:0.321454	val-error:0.330126
# [29]	train-error:0.321544	val-error:0.330126
# [30]	train-error:0.321095	val-error:0.329856
# [31]	train-error:0.320465	val-error:0.329856
# [32]	train-error:0.321027	val-error:0.330036
# [33]	train-error:0.320892	val-error:0.329586
# [34]	train-error:0.320622	val-error:0.330306
# [35]	train-error:0.321027	val-error:0.329946
# [36]	train-error:0.320645	val-error:0.330665
# [37]	train-error:0.321005	val-error:0.330216
# [38]	train-error:0.320825	val-error:0.330216
# [39]	train-error:0.321252	val-error:0.330396
# [40]	train-error:0.321387	val-error:0.330036
# [41]	train-error:0.321657	val-error:0.330576
# [42]	train-error:0.322061	val-error:0.330665
# [43]	train-error:0.322196	val-error:0.330935
# [44]	train-error:0.322196	val-error:0.330935
# [45]	train-error:0.321837	val-error:0.330306
# [46]	train-error:0.321634	val-error:0.330486
# [47]	train-error:0.321792	val-error:0.330576
# [48]	train-error:0.321657	val-error:0.330396
# [49]	train-error:0.321252	val-error:0.330396
# [50]	train-error:0.321274	val-error:0.329856
# [51]	train-error:0.321252	val-error:0.329856
# [52]	train-error:0.321319	val-error:0.330216
# [53]	train-error:0.321342	val-error:0.330396
# [54]	train-error:0.321342	val-error:0.329856
# [55]	train-error:0.321522	val-error:0.330306
# [56]	train-error:0.321612	val-error:0.330306
# [57]	train-error:0.321926	val-error:0.330486
# [58]	train-error:0.321949	val-error:0.330665
# [59]	train-error:0.322151	val-error:0.330665
# [60]	train-error:0.322421	val-error:0.330845
# [61]	train-error:0.322511	val-error:0.330935
# [62]	train-error:0.322533	val-error:0.331025
# [63]	train-error:0.322826	val-error:0.331025
# [64]	train-error:0.322736	val-error:0.330845
# [65]	train-error:0.322848	val-error:0.330576
# [66]	train-error:0.322803	val-error:0.330755
# [67]	train-error:0.322556	val-error:0.330755
# [68]	train-error:0.322444	val-error:0.330755
# [69]	train-error:0.322758	val-error:0.330755
# [70]	train-error:0.322691	val-error:0.330576
# [71]	train-error:0.323006	val-error:0.330576
# [72]	train-error:0.322871	val-error:0.330755
# [73]	train-error:0.323208	val-error:0.331475
# [74]	train-error:0.322961	val-error:0.331205
# [75]	train-error:0.322848	val-error:0.331475
# [76]	train-error:0.322871	val-error:0.331745
# [77]	train-error:0.322826	val-error:0.331565
# [78]	train-error:0.322623	val-error:0.331475
# [79]	train-error:0.322601	val-error:0.331655
# [80]	train-error:0.322623	val-error:0.331295
# [81]	train-error:0.322399	val-error:0.331295
# [82]	train-error:0.322668	val-error:0.331205
# [83]	train-error:0.322713	val-error:0.331115
# [84]	train-error:0.322983	val-error:0.331745
# [85]	train-error:0.323096	val-error:0.331655
# [86]	train-error:0.323096	val-error:0.332104
# [87]	train-error:0.322916	val-error:0.331835
# [88]	train-error:0.322938	val-error:0.331924
# [89]	train-error:0.322781	val-error:0.331924
# [90]	train-error:0.322871	val-error:0.331835
# [91]	train-error:0.322938	val-error:0.331924
# [92]	train-error:0.322713	val-error:0.332014
# [93]	train-error:0.322646	val-error:0.331745
# [94]	train-error:0.322354	val-error:0.331655
# [95]	train-error:0.322376	val-error:0.331385
# [96]	train-error:0.322466	val-error:0.331205
# [97]	train-error:0.322354	val-error:0.331655
# [98]	train-error:0.322309	val-error:0.331835
# [99]	train-error:0.322466	val-error:0.331565
# [100]	train-error:0.322444	val-error:0.331745
# [101]	train-error:0.322286	val-error:0.331565
# [102]	train-error:0.322241	val-error:0.331745
# [103]	train-error:0.322444	val-error:0.332014
# [104]	train-error:0.322286	val-error:0.331835
# [105]	train-error:0.322399	val-error:0.332014
# [106]	train-error:0.322241	val-error:0.332104
# [107]	train-error:0.322151	val-error:0.332104
# [108]	train-error:0.322129	val-error:0.332014
# [109]	train-error:0.321926	val-error:0.331835
# [110]	train-error:0.321949	val-error:0.331655
# [111]	train-error:0.322129	val-error:0.332194
# [112]	train-error:0.322286	val-error:0.332104
# [113]	train-error:0.322286	val-error:0.332104
# [114]	train-error:0.322309	val-error:0.332194
# [115]	train-error:0.322084	val-error:0.331565
# [116]	train-error:0.322016	val-error:0.331745
# [117]	train-error:0.321994	val-error:0.331745
# [118]	train-error:0.321971	val-error:0.331745
# [119]	train-error:0.321702	val-error:0.331745
# [120]	train-error:0.321724	val-error:0.331835
# [121]	train-error:0.321612	val-error:0.332014
# [122]	train-error:0.321634	val-error:0.331924
# [123]	train-error:0.321634	val-error:0.331835
# [124]	train-error:0.321409	val-error:0.331745
# [125]	train-error:0.321364	val-error:0.331745
# [126]	train-error:0.321499	val-error:0.331835
# [127]	train-error:0.321252	val-error:0.331385
# [128]	train-error:0.321229	val-error:0.331295
# [129]	train-error:0.321252	val-error:0.331295
# [130]	train-error:0.320847	val-error:0.330845
# [131]	train-error:0.32096	val-error:0.330845
# [132]	train-error:0.320667	val-error:0.330755
# [133]	train-error:0.320757	val-error:0.330576
# [134]	train-error:0.320487	val-error:0.330486
# [135]	train-error:0.32069	val-error:0.330396
# [136]	train-error:0.32069	val-error:0.330036
# [137]	train-error:0.320555	val-error:0.330036
# [138]	train-error:0.320555	val-error:0.330036
# [139]	train-error:0.320487	val-error:0.330306
# [140]	train-error:0.320532	val-error:0.330126
# [141]	train-error:0.320487	val-error:0.330216
# [142]	train-error:0.3206	val-error:0.330036
# [143]	train-error:0.3206	val-error:0.330126
# [144]	train-error:0.3206	val-error:0.330216
# [145]	train-error:0.320487	val-error:0.330126
# [146]	train-error:0.32024	val-error:0.330036
# [147]	train-error:0.320263	val-error:0.329946
# [148]	train-error:0.320195	val-error:0.330126
# [149]	train-error:0.31997	val-error:0.329856
# [150]	train-error:0.32024	val-error:0.329856
# [151]	train-error:0.32006	val-error:0.329766
# [152]	train-error:0.319925	val-error:0.329856
# [153]	train-error:0.319835	val-error:0.329856
# [154]	train-error:0.31997	val-error:0.329946
# [155]	train-error:0.31997	val-error:0.330036
# [156]	train-error:0.319993	val-error:0.329946
# [157]	train-error:0.31979	val-error:0.329496
# [158]	train-error:0.31979	val-error:0.329406
# [159]	train-error:0.31979	val-error:0.329496
# [160]	train-error:0.319521	val-error:0.329137
# [161]	train-error:0.319476	val-error:0.329047
# [162]	train-error:0.319251	val-error:0.328777
# [163]	train-error:0.319408	val-error:0.328777
# [164]	train-error:0.319183	val-error:0.328687
# [165]	train-error:0.319026	val-error:0.328687
# [166]	train-error:0.319071	val-error:0.328327
# [167]	train-error:0.319071	val-error:0.328147
# [168]	train-error:0.319026	val-error:0.328417
# [169]	train-error:0.318981	val-error:0.328147
# [170]	train-error:0.319026	val-error:0.328147
# [171]	train-error:0.318936	val-error:0.328327
# [172]	train-error:0.318936	val-error:0.328237
# [173]	train-error:0.318891	val-error:0.328327
# [174]	train-error:0.318959	val-error:0.328327
# [175]	train-error:0.318891	val-error:0.327968
# [176]	train-error:0.318824	val-error:0.328058
# [177]	train-error:0.318936	val-error:0.327788
# [178]	train-error:0.318869	val-error:0.328147
# [179]	train-error:0.318689	val-error:0.327608
# [180]	train-error:0.318779	val-error:0.327608
# [181]	train-error:0.318621	val-error:0.327698
# [182]	train-error:0.318599	val-error:0.327428
# [183]	train-error:0.318509	val-error:0.327428
# [184]	train-error:0.318486	val-error:0.327428
# [185]	train-error:0.318486	val-error:0.327338
# [186]	train-error:0.318531	val-error:0.327698
# [187]	train-error:0.318441	val-error:0.327518
# [188]	train-error:0.318419	val-error:0.327428
# [189]	train-error:0.318396	val-error:0.327428
# [190]	train-error:0.318239	val-error:0.327428
# [191]	train-error:0.318082	val-error:0.327428
# [192]	train-error:0.317947	val-error:0.327158
# [193]	train-error:0.317767	val-error:0.327158
# [194]	train-error:0.317699	val-error:0.326799
# [195]	train-error:0.317587	val-error:0.326889
# [196]	train-error:0.317587	val-error:0.326978
# [197]	train-error:0.317295	val-error:0.326889
# [198]	train-error:0.31734	val-error:0.326799
# [199]	train-error:0.317272	val-error:0.326529
# [200]	train-error:0.31698	val-error:0.326529
# [201]	train-error:0.316935	val-error:0.326529
# [202]	train-error:0.316755	val-error:0.326439
# [203]	train-error:0.316755	val-error:0.326709
# [204]	train-error:0.316665	val-error:0.326529
# [205]	train-error:0.316553	val-error:0.326799
# [206]	train-error:0.316395	val-error:0.326619
# [207]	train-error:0.316328	val-error:0.326439
# [208]	train-error:0.316373	val-error:0.326349
# [209]	train-error:0.316328	val-error:0.326439
# [210]	train-error:0.316373	val-error:0.326439
# [211]	train-error:0.316373	val-error:0.326349
# [212]	train-error:0.316485	val-error:0.326349
# [213]	train-error:0.316575	val-error:0.326349
# [214]	train-error:0.316463	val-error:0.326439
# [215]	train-error:0.31653	val-error:0.326259
# [216]	train-error:0.31653	val-error:0.326169
# [217]	train-error:0.316553	val-error:0.326079
# [218]	train-error:0.316418	val-error:0.326259
# [219]	train-error:0.316485	val-error:0.326529
# [220]	train-error:0.316485	val-error:0.326529
# [221]	train-error:0.316418	val-error:0.326709
# [222]	train-error:0.31644	val-error:0.326529
# [223]	train-error:0.316328	val-error:0.326619
# [224]	train-error:0.316283	val-error:0.326529
# [225]	train-error:0.316305	val-error:0.326259
# [226]	train-error:0.316305	val-error:0.326259
# [227]	train-error:0.316283	val-error:0.326169
# [228]	train-error:0.316283	val-error:0.326079
# [229]	train-error:0.316305	val-error:0.325899
# [230]	train-error:0.316283	val-error:0.325809
# [231]	train-error:0.316193	val-error:0.32554
# [232]	train-error:0.316148	val-error:0.325719
# [233]	train-error:0.316058	val-error:0.32554
# [234]	train-error:0.316036	val-error:0.32554
# [235]	train-error:0.316058	val-error:0.32545
# [236]	train-error:0.316058	val-error:0.32536
# [237]	train-error:0.316126	val-error:0.325
# [238]	train-error:0.316081	val-error:0.32509
# [239]	train-error:0.315901	val-error:0.32482
# [240]	train-error:0.315653	val-error:0.32482
# [241]	train-error:0.315721	val-error:0.32482
# [242]	train-error:0.315698	val-error:0.32482
# [243]	train-error:0.315631	val-error:0.32473
# [244]	train-error:0.315653	val-error:0.32518
# [245]	train-error:0.315429	val-error:0.32464
# [246]	train-error:0.315406	val-error:0.32455
# [247]	train-error:0.315226	val-error:0.324371
# [248]	train-error:0.315384	val-error:0.32455
# [249]	train-error:0.315316	val-error:0.324281
# [250]	train-error:0.315294	val-error:0.32455
# [251]	train-error:0.315069	val-error:0.32455
# [252]	train-error:0.315024	val-error:0.32455
# [253]	train-error:0.314934	val-error:0.32446
# [254]	train-error:0.314799	val-error:0.32446
# [255]	train-error:0.314777	val-error:0.324281
# [256]	train-error:0.314732	val-error:0.32446
# [257]	train-error:0.314529	val-error:0.324281
# [258]	train-error:0.314417	val-error:0.323921
# [259]	train-error:0.314417	val-error:0.323921
# [260]	train-error:0.314394	val-error:0.324101
# [261]	train-error:0.314304	val-error:0.323921
# [262]	train-error:0.314237	val-error:0.324011
# [263]	train-error:0.314192	val-error:0.323741
# [264]	train-error:0.314057	val-error:0.323921
# [265]	train-error:0.314012	val-error:0.323741
# [266]	train-error:0.313832	val-error:0.323381
# [267]	train-error:0.313855	val-error:0.323381
# [268]	train-error:0.313832	val-error:0.323291
# [269]	train-error:0.313855	val-error:0.323291
# [270]	train-error:0.313765	val-error:0.323291
# [271]	train-error:0.31372	val-error:0.323381
# [272]	train-error:0.313855	val-error:0.323471
# [273]	train-error:0.313832	val-error:0.323561
# [274]	train-error:0.313697	val-error:0.323561
# [275]	train-error:0.31363	val-error:0.323471
# [276]	train-error:0.313652	val-error:0.323381
# [277]	train-error:0.31363	val-error:0.323201
# [278]	train-error:0.313562	val-error:0.322932
# [279]	train-error:0.313562	val-error:0.322752
# [280]	train-error:0.313697	val-error:0.322662
# [281]	train-error:0.313607	val-error:0.322662
# [282]	train-error:0.31354	val-error:0.322842
# [283]	train-error:0.313427	val-error:0.322572
# [284]	train-error:0.313338	val-error:0.322392
# [285]	train-error:0.31327	val-error:0.322482
# [286]	train-error:0.313068	val-error:0.322212
# [287]	train-error:0.313	val-error:0.322302
# [288]	train-error:0.312933	val-error:0.322392
# [289]	train-error:0.31282	val-error:0.322302
# [290]	train-error:0.312798	val-error:0.321853
# [291]	train-error:0.312753	val-error:0.322032
# [292]	train-error:0.31273	val-error:0.322302
# [293]	train-error:0.312663	val-error:0.322212
# [294]	train-error:0.312685	val-error:0.321942
# [295]	train-error:0.31273	val-error:0.321942
# [296]	train-error:0.312708	val-error:0.322032
# [297]	train-error:0.312775	val-error:0.322212
# [298]	train-error:0.312685	val-error:0.322032
# [299]	train-error:0.312775	val-error:0.321942
# [300]	train-error:0.312663	val-error:0.322032
# [301]	train-error:0.312596	val-error:0.321673
# [302]	train-error:0.312618	val-error:0.321673
# [303]	train-error:0.312618	val-error:0.321583
# [304]	train-error:0.312393	val-error:0.321583
# [305]	train-error:0.312461	val-error:0.321583
# [306]	train-error:0.312506	val-error:0.321853
# [307]	train-error:0.312416	val-error:0.321493
# [308]	train-error:0.312281	val-error:0.321313
# [309]	train-error:0.312258	val-error:0.321403
# [310]	train-error:0.312191	val-error:0.321403
# [311]	train-error:0.312056	val-error:0.321223
# [312]	train-error:0.312033	val-error:0.321223
# [313]	train-error:0.312056	val-error:0.321403
# [314]	train-error:0.311966	val-error:0.321313
# [315]	train-error:0.311921	val-error:0.321223
# [316]	train-error:0.311899	val-error:0.321133
# [317]	train-error:0.311764	val-error:0.321133
# [318]	train-error:0.311719	val-error:0.320863
# [319]	train-error:0.311584	val-error:0.320594
# [320]	train-error:0.311471	val-error:0.320773
# [321]	train-error:0.311426	val-error:0.320953
# [322]	train-error:0.311449	val-error:0.320773
# [323]	train-error:0.311381	val-error:0.320773
# [324]	train-error:0.311179	val-error:0.320683
# [325]	train-error:0.310999	val-error:0.320594
# [326]	train-error:0.310954	val-error:0.320683
# [327]	train-error:0.310932	val-error:0.320683
# [328]	train-error:0.310909	val-error:0.320773
# [329]	train-error:0.310954	val-error:0.320773
# [330]	train-error:0.310999	val-error:0.320683
# [331]	train-error:0.310954	val-error:0.320683
# [332]	train-error:0.310684	val-error:0.320683
# [333]	train-error:0.31046	val-error:0.320414
# [334]	train-error:0.31037	val-error:0.320234
# [335]	train-error:0.310415	val-error:0.320414
# [336]	train-error:0.31037	val-error:0.320414
# [337]	train-error:0.310302	val-error:0.320594
# [338]	train-error:0.31019	val-error:0.320594
# [339]	train-error:0.310122	val-error:0.320414
# [340]	train-error:0.31001	val-error:0.320324
# [341]	train-error:0.31001	val-error:0.320594
# [342]	train-error:0.309897	val-error:0.320234
# [343]	train-error:0.30974	val-error:0.320054
# [344]	train-error:0.309718	val-error:0.319874
# [345]	train-error:0.30983	val-error:0.319874
# [346]	train-error:0.309808	val-error:0.319784
# [347]	train-error:0.30983	val-error:0.319784
# [348]	train-error:0.309695	val-error:0.319335
# [349]	train-error:0.30965	val-error:0.319335
# [350]	train-error:0.309605	val-error:0.319335
# [351]	train-error:0.30947	val-error:0.319424
# [352]	train-error:0.309358	val-error:0.319335
# [353]	train-error:0.309268	val-error:0.319424
# [354]	train-error:0.309335	val-error:0.319424
# [355]	train-error:0.309358	val-error:0.319514
# [356]	train-error:0.309245	val-error:0.319604
# [357]	train-error:0.309155	val-error:0.319514
# [358]	train-error:0.309111	val-error:0.319335
# [359]	train-error:0.309111	val-error:0.319424
# [360]	train-error:0.309066	val-error:0.319155
# [361]	train-error:0.308931	val-error:0.319155
# [362]	train-error:0.308706	val-error:0.319245
# [363]	train-error:0.308706	val-error:0.319155
# [364]	train-error:0.308616	val-error:0.319065
# [365]	train-error:0.308593	val-error:0.318795
# [366]	train-error:0.308121	val-error:0.318615
# [367]	train-error:0.308054	val-error:0.318435
# [368]	train-error:0.308009	val-error:0.318345
# [369]	train-error:0.307986	val-error:0.318525
# [370]	train-error:0.307806	val-error:0.318525
# [371]	train-error:0.307784	val-error:0.318705
# [372]	train-error:0.307739	val-error:0.318435
# [373]	train-error:0.307627	val-error:0.318255
# [374]	train-error:0.307582	val-error:0.318345
# [375]	train-error:0.307514	val-error:0.318345
# [376]	train-error:0.307424	val-error:0.318165
# [377]	train-error:0.307334	val-error:0.318165
# [378]	train-error:0.307312	val-error:0.318255
# [379]	train-error:0.307199	val-error:0.318165
# [380]	train-error:0.307154	val-error:0.317806
# [381]	train-error:0.307042	val-error:0.317626
# [382]	train-error:0.30693	val-error:0.317716
# [383]	train-error:0.306975	val-error:0.317536
# [384]	train-error:0.30693	val-error:0.317716
# [385]	train-error:0.306727	val-error:0.317626
# [386]	train-error:0.306682	val-error:0.317536
# [387]	train-error:0.30666	val-error:0.317446
# [388]	train-error:0.306615	val-error:0.317176
# [389]	train-error:0.306592	val-error:0.316996
# [390]	train-error:0.306367	val-error:0.316996
# [391]	train-error:0.3063	val-error:0.316996
# [392]	train-error:0.306278	val-error:0.317176
# [393]	train-error:0.306278	val-error:0.317176
# [394]	train-error:0.30621	val-error:0.316906
# [395]	train-error:0.30612	val-error:0.317176
# [396]	train-error:0.306143	val-error:0.316906
# [397]	train-error:0.306053	val-error:0.316817
# [398]	train-error:0.305828	val-error:0.316817
# [399]	train-error:0.30576	val-error:0.316817
# [400]	train-error:0.30576	val-error:0.316817
# [401]	train-error:0.305738	val-error:0.316727
# [402]	train-error:0.305648	val-error:0.316457
# [403]	train-error:0.305625	val-error:0.316637
# [404]	train-error:0.305491	val-error:0.316187
# [405]	train-error:0.305446	val-error:0.316097
# [406]	train-error:0.305333	val-error:0.316187
# [407]	train-error:0.305243	val-error:0.316007
# [408]	train-error:0.305086	val-error:0.316097
# [409]	train-error:0.305108	val-error:0.316007
# [410]	train-error:0.305041	val-error:0.315827
# [411]	train-error:0.304794	val-error:0.315827
# [412]	train-error:0.304704	val-error:0.315827
# [413]	train-error:0.304569	val-error:0.315737
# [414]	train-error:0.304434	val-error:0.315647
# [415]	train-error:0.304434	val-error:0.315468
# [416]	train-error:0.304321	val-error:0.315468
# [417]	train-error:0.304276	val-error:0.315468
# [418]	train-error:0.304299	val-error:0.315378
# [419]	train-error:0.304254	val-error:0.315468
# [420]	train-error:0.304029	val-error:0.315468
# [421]	train-error:0.303939	val-error:0.315558
# [422]	train-error:0.303894	val-error:0.315468
# [423]	train-error:0.303782	val-error:0.315558
# [424]	train-error:0.303737	val-error:0.315647
# [425]	train-error:0.303737	val-error:0.315647
# [426]	train-error:0.303557	val-error:0.315468
# [427]	train-error:0.30349	val-error:0.315468
# [428]	train-error:0.3034	val-error:0.315468
# [429]	train-error:0.303445	val-error:0.315288
# [430]	train-error:0.303332	val-error:0.315378
# [431]	train-error:0.303265	val-error:0.315288
# [432]	train-error:0.303062	val-error:0.315198
# [433]	train-error:0.30304	val-error:0.315018
# [434]	train-error:0.302927	val-error:0.314928
# [435]	train-error:0.303062	val-error:0.314748
# [436]	train-error:0.302748	val-error:0.314748
# [437]	train-error:0.302748	val-error:0.314748
# [438]	train-error:0.30268	val-error:0.314658
# [439]	train-error:0.302635	val-error:0.314748
# [440]	train-error:0.30259	val-error:0.314568
# [441]	train-error:0.302545	val-error:0.314568
# [442]	train-error:0.302365	val-error:0.314478
# [443]	train-error:0.30223	val-error:0.314388
# [444]	train-error:0.302298	val-error:0.314478
# [445]	train-error:0.30223	val-error:0.314299
# [446]	train-error:0.30223	val-error:0.314029
# [447]	train-error:0.30214	val-error:0.314029
# [448]	train-error:0.302073	val-error:0.313759
# [449]	train-error:0.302028	val-error:0.313579
# [450]	train-error:0.301916	val-error:0.313849
# [451]	train-error:0.301803	val-error:0.313489
# [452]	train-error:0.301623	val-error:0.313309
# [453]	train-error:0.301556	val-error:0.313309
# [454]	train-error:0.301443	val-error:0.313399
# [455]	train-error:0.301578	val-error:0.313489
# [456]	train-error:0.301376	val-error:0.313669
# [457]	train-error:0.301286	val-error:0.313579
# [458]	train-error:0.301354	val-error:0.313489
# [459]	train-error:0.301264	val-error:0.313309
# [460]	train-error:0.301174	val-error:0.313219
# [461]	train-error:0.301084	val-error:0.313219
# [462]	train-error:0.300994	val-error:0.313129
# [463]	train-error:0.301016	val-error:0.31295
# [464]	train-error:0.300791	val-error:0.31277
# [465]	train-error:0.300657	val-error:0.31286
# [466]	train-error:0.300567	val-error:0.31268
# [467]	train-error:0.300544	val-error:0.31268
# [468]	train-error:0.300544	val-error:0.31259
# [469]	train-error:0.300364	val-error:0.31259
# [470]	train-error:0.300409	val-error:0.3125
# [471]	train-error:0.300252	val-error:0.31232
# [472]	train-error:0.300049	val-error:0.31205
# [473]	train-error:0.300049	val-error:0.311781
# [474]	train-error:0.300027	val-error:0.31196
# [475]	train-error:0.29996	val-error:0.311691
# [476]	train-error:0.300004	val-error:0.311691
# [477]	train-error:0.299892	val-error:0.311781
# [478]	train-error:0.299892	val-error:0.311331
# [479]	train-error:0.299847	val-error:0.311241
# [480]	train-error:0.299825	val-error:0.311241
# [481]	train-error:0.299735	val-error:0.311241
# [482]	train-error:0.29969	val-error:0.311151
# [483]	train-error:0.299645	val-error:0.311151
# [484]	train-error:0.299622	val-error:0.311151
# [485]	train-error:0.299532	val-error:0.310971
# [486]	train-error:0.29951	val-error:0.310971
# [487]	train-error:0.299375	val-error:0.310971
# [488]	train-error:0.299307	val-error:0.310881
# [489]	train-error:0.299105	val-error:0.310971
# [490]	train-error:0.298993	val-error:0.310522
# [491]	train-error:0.29888	val-error:0.310522
# [492]	train-error:0.298813	val-error:0.310342
# [493]	train-error:0.298745	val-error:0.310342
# [494]	train-error:0.29879	val-error:0.310432
# [495]	train-error:0.298745	val-error:0.310162
# [496]	train-error:0.298655	val-error:0.310342
# [497]	train-error:0.298431	val-error:0.310252
# [498]	train-error:0.298386	val-error:0.310252
# [499]	train-error:0.298318	val-error:0.310252
# [500]	train-error:0.298318	val-error:0.310342
# [501]	train-error:0.298161	val-error:0.310162
# [502]	train-error:0.298048	val-error:0.310162
# [503]	train-error:0.298071	val-error:0.309982
# [504]	train-error:0.298116	val-error:0.309892
# [505]	train-error:0.298093	val-error:0.309802
# [506]	train-error:0.298138	val-error:0.310072
# [507]	train-error:0.297981	val-error:0.309802
# [508]	train-error:0.297801	val-error:0.309712
# [509]	train-error:0.297756	val-error:0.309712
# [510]	train-error:0.297621	val-error:0.309442
# [511]	train-error:0.297576	val-error:0.309712
# [512]	train-error:0.297509	val-error:0.309712
# [513]	train-error:0.297419	val-error:0.309622
# [514]	train-error:0.297351	val-error:0.309712
# [515]	train-error:0.297329	val-error:0.309622
# [516]	train-error:0.297284	val-error:0.309532
# [517]	train-error:0.297261	val-error:0.309622
# [518]	train-error:0.297194	val-error:0.309532
# [519]	train-error:0.297127	val-error:0.309442
# [520]	train-error:0.297059	val-error:0.309353
# [521]	train-error:0.296879	val-error:0.309083
# [522]	train-error:0.296924	val-error:0.309173
# [523]	train-error:0.296812	val-error:0.309173
# [524]	train-error:0.296812	val-error:0.309173
# [525]	train-error:0.296722	val-error:0.309173
# [526]	train-error:0.296654	val-error:0.309173
# [527]	train-error:0.296564	val-error:0.309173
# [528]	train-error:0.296452	val-error:0.309173
# [529]	train-error:0.296452	val-error:0.309083
# [530]	train-error:0.296385	val-error:0.309173
# [531]	train-error:0.296295	val-error:0.308993
# [532]	train-error:0.29625	val-error:0.309083
# [533]	train-error:0.296047	val-error:0.309083
# [534]	train-error:0.295912	val-error:0.309083
# [535]	train-error:0.295822	val-error:0.308993
# [536]	train-error:0.295755	val-error:0.309083
# [537]	train-error:0.295845	val-error:0.309263
# [538]	train-error:0.295755	val-error:0.309173
# [539]	train-error:0.295643	val-error:0.309083
# [540]	train-error:0.295598	val-error:0.308903
# [541]	train-error:0.295575	val-error:0.308723
# [542]	train-error:0.295463	val-error:0.308453
# [543]	train-error:0.295215	val-error:0.308543
# [544]	train-error:0.295103	val-error:0.308543
# [545]	train-error:0.295125	val-error:0.308453
# [546]	train-error:0.295013	val-error:0.308453
# [547]	train-error:0.294923	val-error:0.308273
# [548]	train-error:0.294856	val-error:0.308363
# [549]	train-error:0.294653	val-error:0.308363
# [550]	train-error:0.294563	val-error:0.308543
# [551]	train-error:0.294428	val-error:0.308453
# [552]	train-error:0.294473	val-error:0.308543
# [553]	train-error:0.294406	val-error:0.308453
# [554]	train-error:0.294361	val-error:0.308453
# [555]	train-error:0.294339	val-error:0.308453
# [556]	train-error:0.294316	val-error:0.308453
# [557]	train-error:0.294271	val-error:0.308543
# [558]	train-error:0.294226	val-error:0.308453
# [559]	train-error:0.294226	val-error:0.308453
# [560]	train-error:0.294136	val-error:0.308543
# [561]	train-error:0.294046	val-error:0.308363
# [562]	train-error:0.293844	val-error:0.308363
# [563]	train-error:0.293934	val-error:0.308273
# [564]	train-error:0.293934	val-error:0.308273
# [565]	train-error:0.293844	val-error:0.308094
# [566]	train-error:0.293776	val-error:0.307914
# [567]	train-error:0.293642	val-error:0.308004
# [568]	train-error:0.293507	val-error:0.307914
# [569]	train-error:0.293417	val-error:0.307914
# [570]	train-error:0.293394	val-error:0.307734
# [571]	train-error:0.293259	val-error:0.307554
# [572]	train-error:0.293237	val-error:0.307644
# [573]	train-error:0.293304	val-error:0.307734
# [574]	train-error:0.293349	val-error:0.307824
# [575]	train-error:0.293237	val-error:0.307464
# [576]	train-error:0.293214	val-error:0.307464
# [577]	train-error:0.293124	val-error:0.307644
# [578]	train-error:0.292989	val-error:0.307464
# [579]	train-error:0.292922	val-error:0.307554
# [580]	train-error:0.292967	val-error:0.307464
# [581]	train-error:0.292855	val-error:0.307464
# [582]	train-error:0.292787	val-error:0.307464
# [583]	train-error:0.292877	val-error:0.307374
# [584]	train-error:0.292832	val-error:0.307374
# [585]	train-error:0.292855	val-error:0.307464
# [586]	train-error:0.292787	val-error:0.307464
# [587]	train-error:0.292877	val-error:0.307644
# [588]	train-error:0.29272	val-error:0.307554
# [589]	train-error:0.29263	val-error:0.307464
# [590]	train-error:0.29263	val-error:0.307374
# [591]	train-error:0.292607	val-error:0.307374
# [592]	train-error:0.292607	val-error:0.307194
# [593]	train-error:0.292607	val-error:0.307374
# [594]	train-error:0.292517	val-error:0.307374
# [595]	train-error:0.292585	val-error:0.307194
# [596]	train-error:0.29254	val-error:0.307104
# [597]	train-error:0.292517	val-error:0.307104
# [598]	train-error:0.292405	val-error:0.307284
# [599]	train-error:0.292382	val-error:0.307104
# [600]	train-error:0.29227	val-error:0.307014
# [601]	train-error:0.292135	val-error:0.307104
# [602]	train-error:0.292135	val-error:0.307194
# [603]	train-error:0.292068	val-error:0.307374
# [604]	train-error:0.291955	val-error:0.307104
# [605]	train-error:0.291798	val-error:0.307014
# [606]	train-error:0.291775	val-error:0.307014
# [607]	train-error:0.291708	val-error:0.307374
# [608]	train-error:0.291618	val-error:0.307194
# [609]	train-error:0.291618	val-error:0.307284
# [610]	train-error:0.291685	val-error:0.307104
# [611]	train-error:0.291685	val-error:0.307194
# [612]	train-error:0.291775	val-error:0.307194
# [613]	train-error:0.291753	val-error:0.307194
# [614]	train-error:0.291663	val-error:0.307104
# [615]	train-error:0.291618	val-error:0.307194
# [616]	train-error:0.29155	val-error:0.307194
# [617]	train-error:0.291573	val-error:0.307104
# [618]	train-error:0.291506	val-error:0.306924
# [619]	train-error:0.291416	val-error:0.306835
# [620]	train-error:0.291348	val-error:0.306924
# [621]	train-error:0.291213	val-error:0.306835
# [622]	train-error:0.291168	val-error:0.306835
# [623]	train-error:0.291078	val-error:0.306745
# [624]	train-error:0.290943	val-error:0.306835
# [625]	train-error:0.290943	val-error:0.306835
# [626]	train-error:0.290854	val-error:0.306565
# [627]	train-error:0.290898	val-error:0.306565
# [628]	train-error:0.290921	val-error:0.306655
# [629]	train-error:0.290876	val-error:0.306385
# [630]	train-error:0.290809	val-error:0.306025
# [631]	train-error:0.290831	val-error:0.306295
# [632]	train-error:0.290719	val-error:0.306385
# [633]	train-error:0.290719	val-error:0.306205
# [634]	train-error:0.290674	val-error:0.306025
# [635]	train-error:0.290629	val-error:0.305935
# [636]	train-error:0.290651	val-error:0.306025
# [637]	train-error:0.290606	val-error:0.306205
# [638]	train-error:0.290629	val-error:0.306205
# [639]	train-error:0.290561	val-error:0.306025
# [640]	train-error:0.290381	val-error:0.306115
# [641]	train-error:0.290404	val-error:0.305935
# [642]	train-error:0.290381	val-error:0.305935
# [643]	train-error:0.290359	val-error:0.305665
# [644]	train-error:0.290359	val-error:0.305665
# [645]	train-error:0.290426	val-error:0.305755
# [646]	train-error:0.290336	val-error:0.305755
# [647]	train-error:0.290224	val-error:0.305665
# [648]	train-error:0.290201	val-error:0.305486
# [649]	train-error:0.289999	val-error:0.305576
# [650]	train-error:0.290044	val-error:0.305396
# [651]	train-error:0.289932	val-error:0.305665
# [652]	train-error:0.289977	val-error:0.305665
# [653]	train-error:0.289887	val-error:0.305486
# [654]	train-error:0.289819	val-error:0.305306
# [655]	train-error:0.289819	val-error:0.305306
# [656]	train-error:0.289842	val-error:0.305306
# [657]	train-error:0.289819	val-error:0.305396
# [658]	train-error:0.289909	val-error:0.305126
# [659]	train-error:0.289864	val-error:0.305216
# [660]	train-error:0.289819	val-error:0.305216
# [661]	train-error:0.289819	val-error:0.305216
# [662]	train-error:0.289684	val-error:0.305036
# [663]	train-error:0.289752	val-error:0.305036
# [664]	train-error:0.289774	val-error:0.304856
# [665]	train-error:0.289662	val-error:0.304856
# [666]	train-error:0.289617	val-error:0.305036
# [667]	train-error:0.289549	val-error:0.305126
# [668]	train-error:0.289572	val-error:0.305126
# [669]	train-error:0.289572	val-error:0.305036
# [670]	train-error:0.289594	val-error:0.304946
# [671]	train-error:0.289549	val-error:0.304946
# [672]	train-error:0.289482	val-error:0.304856
# [673]	train-error:0.289415	val-error:0.304766
# [674]	train-error:0.289325	val-error:0.304766
# [675]	train-error:0.28928	val-error:0.304676
# [676]	train-error:0.28919	val-error:0.304586
# [677]	train-error:0.289077	val-error:0.304317
# [678]	train-error:0.289055	val-error:0.304137
# [679]	train-error:0.288965	val-error:0.304406
# [680]	train-error:0.288897	val-error:0.304227
# [681]	train-error:0.28883	val-error:0.304227
# [682]	train-error:0.288807	val-error:0.304317
# [683]	train-error:0.288762	val-error:0.304047
# [684]	train-error:0.288762	val-error:0.304137
# [685]	train-error:0.288583	val-error:0.303957
# [686]	train-error:0.28856	val-error:0.304137
# [687]	train-error:0.28856	val-error:0.304227
# [688]	train-error:0.288695	val-error:0.304137
# [689]	train-error:0.288583	val-error:0.303957
# [690]	train-error:0.288538	val-error:0.303957
# [691]	train-error:0.288515	val-error:0.303957
# [692]	train-error:0.288425	val-error:0.304047
# [693]	train-error:0.288313	val-error:0.303867
# [694]	train-error:0.288245	val-error:0.303867
# [695]	train-error:0.2882	val-error:0.303957
# [696]	train-error:0.288178	val-error:0.303867
# [697]	train-error:0.288065	val-error:0.303957
# [698]	train-error:0.287931	val-error:0.303777
# [699]	train-error:0.287953	val-error:0.303957
# [700]	train-error:0.288043	val-error:0.303777
# [701]	train-error:0.287998	val-error:0.303957
# [702]	train-error:0.287953	val-error:0.303777
# [703]	train-error:0.287818	val-error:0.303507
# [704]	train-error:0.287818	val-error:0.303507
# [705]	train-error:0.287796	val-error:0.303417
# [706]	train-error:0.287661	val-error:0.303237
# [707]	train-error:0.287616	val-error:0.303417
# [708]	train-error:0.287391	val-error:0.303417
# [709]	train-error:0.287368	val-error:0.303147
# [710]	train-error:0.287391	val-error:0.302968
# [711]	train-error:0.287391	val-error:0.302968
# [712]	train-error:0.287346	val-error:0.302968
# [713]	train-error:0.287256	val-error:0.302968
# [714]	train-error:0.287234	val-error:0.302788
# [715]	train-error:0.287189	val-error:0.302878
# [716]	train-error:0.287211	val-error:0.302968
# [717]	train-error:0.287211	val-error:0.303327
# [718]	train-error:0.287166	val-error:0.303237
# [719]	train-error:0.287054	val-error:0.302968
# [720]	train-error:0.287054	val-error:0.302788
# [721]	train-error:0.286986	val-error:0.302698
# [722]	train-error:0.286941	val-error:0.302518
# [723]	train-error:0.286919	val-error:0.302698
# [724]	train-error:0.286806	val-error:0.302788
# [725]	train-error:0.286806	val-error:0.302518
# [726]	train-error:0.286739	val-error:0.302338
# [727]	train-error:0.286716	val-error:0.302428
# [728]	train-error:0.286739	val-error:0.302518
# [729]	train-error:0.286761	val-error:0.302698
# [730]	train-error:0.286761	val-error:0.302788
# [731]	train-error:0.286671	val-error:0.302698
# [732]	train-error:0.286739	val-error:0.302698
# [733]	train-error:0.286649	val-error:0.302608
# [734]	train-error:0.286694	val-error:0.302698
# [735]	train-error:0.286694	val-error:0.302428
# [736]	train-error:0.286716	val-error:0.302428
# [737]	train-error:0.286604	val-error:0.302338
# [738]	train-error:0.286537	val-error:0.302158
# [739]	train-error:0.286559	val-error:0.301978
# [740]	train-error:0.286492	val-error:0.302158
# [741]	train-error:0.286447	val-error:0.302248
# [742]	train-error:0.286289	val-error:0.302158
# [743]	train-error:0.286312	val-error:0.302248
# [744]	train-error:0.286244	val-error:0.301978
# [745]	train-error:0.286177	val-error:0.301978
# [746]	train-error:0.286154	val-error:0.301978
# [747]	train-error:0.286154	val-error:0.301978
# [748]	train-error:0.286019	val-error:0.301978
# [749]	train-error:0.285997	val-error:0.301799
# [750]	train-error:0.286087	val-error:0.301709
# [751]	train-error:0.285997	val-error:0.301619
# [752]	train-error:0.285997	val-error:0.301619
# [753]	train-error:0.285974	val-error:0.301709
# [754]	train-error:0.286019	val-error:0.301709
# [755]	train-error:0.286042	val-error:0.301978
# [756]	train-error:0.285974	val-error:0.301888
# [757]	train-error:0.28593	val-error:0.301888
# [758]	train-error:0.285862	val-error:0.301888
# [759]	train-error:0.285795	val-error:0.301799
# [760]	train-error:0.285727	val-error:0.301888
# [761]	train-error:0.28575	val-error:0.301709
# [762]	train-error:0.285705	val-error:0.301529
# [763]	train-error:0.28575	val-error:0.301619
# [764]	train-error:0.28566	val-error:0.301619
# [765]	train-error:0.285547	val-error:0.301888
# [766]	train-error:0.285592	val-error:0.301888
# [767]	train-error:0.28557	val-error:0.301619
# [768]	train-error:0.285502	val-error:0.301619
# [769]	train-error:0.285412	val-error:0.301619
# [770]	train-error:0.28539	val-error:0.301439
# [771]	train-error:0.285255	val-error:0.301349
# [772]	train-error:0.285165	val-error:0.301259
# [773]	train-error:0.28503	val-error:0.301169
# [774]	train-error:0.285008	val-error:0.301079
# [775]	train-error:0.285075	val-error:0.301169
# [776]	train-error:0.28503	val-error:0.300989
# [777]	train-error:0.28512	val-error:0.301079
# [778]	train-error:0.285053	val-error:0.300989
# [779]	train-error:0.28494	val-error:0.300899
# [780]	train-error:0.284873	val-error:0.300629
# [781]	train-error:0.284805	val-error:0.300629
# [782]	train-error:0.284783	val-error:0.300719
# [783]	train-error:0.284783	val-error:0.30054
# [784]	train-error:0.28476	val-error:0.300629
# [785]	train-error:0.284783	val-error:0.300629
# [786]	train-error:0.284625	val-error:0.30054
# [787]	train-error:0.284625	val-error:0.30054
# [788]	train-error:0.284513	val-error:0.30054
# [789]	train-error:0.284513	val-error:0.300629
# [790]	train-error:0.284356	val-error:0.30054
# [791]	train-error:0.284356	val-error:0.30054
# [792]	train-error:0.284333	val-error:0.30054
# [793]	train-error:0.284356	val-error:0.30045
# [794]	train-error:0.284356	val-error:0.30045
# [795]	train-error:0.284333	val-error:0.30036
# [796]	train-error:0.284311	val-error:0.30036
# [797]	train-error:0.284288	val-error:0.30036
# [798]	train-error:0.284221	val-error:0.30036
# [799]	train-error:0.284221	val-error:0.30045
# [800]	train-error:0.284198	val-error:0.30045
# [801]	train-error:0.284221	val-error:0.30054
# [802]	train-error:0.284176	val-error:0.30054
# [803]	train-error:0.284176	val-error:0.30054
# [804]	train-error:0.284086	val-error:0.30045
# [805]	train-error:0.284063	val-error:0.30054
# [806]	train-error:0.284086	val-error:0.30027
# [807]	train-error:0.284041	val-error:0.30018
# [808]	train-error:0.284018	val-error:0.30027
# [809]	train-error:0.283996	val-error:0.30036
# [810]	train-error:0.283973	val-error:0.30036
# [811]	train-error:0.283973	val-error:0.30036
# [812]	train-error:0.283951	val-error:0.30027
# [813]	train-error:0.283951	val-error:0.30009
# [814]	train-error:0.283928	val-error:0.3
# [815]	train-error:0.283816	val-error:0.29991
# [816]	train-error:0.283659	val-error:0.3
# [817]	train-error:0.283569	val-error:0.30009
# [818]	train-error:0.283569	val-error:0.30009
# [819]	train-error:0.283569	val-error:0.30009
# [820]	train-error:0.283614	val-error:0.30027
# [821]	train-error:0.283636	val-error:0.3
# [822]	train-error:0.283546	val-error:0.29982
# [823]	train-error:0.283546	val-error:0.29991
# [824]	train-error:0.283501	val-error:0.30009
# [825]	train-error:0.283479	val-error:0.29973
# [826]	train-error:0.283321	val-error:0.29973
# [827]	train-error:0.283209	val-error:0.29973
# [828]	train-error:0.283096	val-error:0.29955
# [829]	train-error:0.283052	val-error:0.29973
# [830]	train-error:0.283074	val-error:0.29973
# [831]	train-error:0.283074	val-error:0.29973
# [832]	train-error:0.283029	val-error:0.29991
# [833]	train-error:0.282939	val-error:0.29991
# [834]	train-error:0.282917	val-error:0.29973
# [835]	train-error:0.282894	val-error:0.29991
# [836]	train-error:0.282917	val-error:0.29982
# [837]	train-error:0.282917	val-error:0.3
# [838]	train-error:0.282782	val-error:0.3
# [839]	train-error:0.282714	val-error:0.29991
# [840]	train-error:0.282669	val-error:0.29991
# [841]	train-error:0.282692	val-error:0.3
# [842]	train-error:0.282534	val-error:0.30009
# [843]	train-error:0.282512	val-error:0.30009
# [844]	train-error:0.282332	val-error:0.29991
# [845]	train-error:0.28231	val-error:0.29991
# [846]	train-error:0.282197	val-error:0.29973
# [847]	train-error:0.282175	val-error:0.29991
# [848]	train-error:0.28204	val-error:0.29955
# [849]	train-error:0.281927	val-error:0.29937
# [850]	train-error:0.281882	val-error:0.29955
# [851]	train-error:0.281927	val-error:0.29955
# [852]	train-error:0.281882	val-error:0.29964
# [853]	train-error:0.281882	val-error:0.29973
# [854]	train-error:0.281815	val-error:0.29982
# [855]	train-error:0.281815	val-error:0.29973
# [856]	train-error:0.281725	val-error:0.29955
# [857]	train-error:0.281658	val-error:0.29964
# [858]	train-error:0.281658	val-error:0.29964
# [859]	train-error:0.281478	val-error:0.29955
# [860]	train-error:0.281365	val-error:0.29937
# [861]	train-error:0.281298	val-error:0.299191
# [862]	train-error:0.281275	val-error:0.29937
# [863]	train-error:0.281298	val-error:0.299281
# [864]	train-error:0.281095	val-error:0.299011
# [865]	train-error:0.281028	val-error:0.298921
# [866]	train-error:0.280893	val-error:0.298921
# [867]	train-error:0.280893	val-error:0.298831
# [868]	train-error:0.280848	val-error:0.298921
# [869]	train-error:0.280848	val-error:0.298831
# [870]	train-error:0.280736	val-error:0.298831
# [871]	train-error:0.280556	val-error:0.298741
# [872]	train-error:0.280466	val-error:0.298921
# [873]	train-error:0.280511	val-error:0.298831
# [874]	train-error:0.280443	val-error:0.298831
# [875]	train-error:0.280331	val-error:0.298651
# [876]	train-error:0.280308	val-error:0.298561
# [877]	train-error:0.280353	val-error:0.298471
# [878]	train-error:0.280331	val-error:0.298471
# [879]	train-error:0.280376	val-error:0.298471
# [880]	train-error:0.280398	val-error:0.298471
# [881]	train-error:0.280353	val-error:0.298561
# [882]	train-error:0.280308	val-error:0.298561
# [883]	train-error:0.280286	val-error:0.298561
# [884]	train-error:0.280129	val-error:0.298561
# [885]	train-error:0.280084	val-error:0.298651
# [886]	train-error:0.280106	val-error:0.298111
# [887]	train-error:0.280106	val-error:0.297932
# [888]	train-error:0.280106	val-error:0.298022
# [889]	train-error:0.280061	val-error:0.298022
# [890]	train-error:0.280061	val-error:0.298022
# [891]	train-error:0.280016	val-error:0.298111
# [892]	train-error:0.280039	val-error:0.298022
# [893]	train-error:0.279926	val-error:0.298022
# [894]	train-error:0.279881	val-error:0.298111
# [895]	train-error:0.279836	val-error:0.297932
# [896]	train-error:0.279836	val-error:0.298022
# [897]	train-error:0.279701	val-error:0.297932
# [898]	train-error:0.279679	val-error:0.297842
# [899]	train-error:0.279566	val-error:0.297842
# [900]	train-error:0.279589	val-error:0.297932
# [901]	train-error:0.279544	val-error:0.297752
# [902]	train-error:0.279544	val-error:0.297662
# [903]	train-error:0.279477	val-error:0.297932
# [904]	train-error:0.279454	val-error:0.297932
# [905]	train-error:0.279252	val-error:0.297752
# [906]	train-error:0.279252	val-error:0.297842
# [907]	train-error:0.279207	val-error:0.297932
# [908]	train-error:0.279162	val-error:0.297842
# [909]	train-error:0.279184	val-error:0.297752
# [910]	train-error:0.279139	val-error:0.297752
# [911]	train-error:0.279027	val-error:0.297842
# [912]	train-error:0.278982	val-error:0.297662
# [913]	train-error:0.279049	val-error:0.297572
# [914]	train-error:0.279072	val-error:0.297662
# [915]	train-error:0.278937	val-error:0.297482
# [916]	train-error:0.278914	val-error:0.297662
# [917]	train-error:0.278802	val-error:0.297392
# [918]	train-error:0.27878	val-error:0.297302
# [919]	train-error:0.278735	val-error:0.297212
# [920]	train-error:0.27878	val-error:0.297212
# [921]	train-error:0.278735	val-error:0.297302
# [922]	train-error:0.278735	val-error:0.297302
# [923]	train-error:0.278757	val-error:0.297212
# [924]	train-error:0.278757	val-error:0.297302
# [925]	train-error:0.278712	val-error:0.297392
# [926]	train-error:0.278712	val-error:0.297482
# [927]	train-error:0.278735	val-error:0.297392
# [928]	train-error:0.278757	val-error:0.297302
# [929]	train-error:0.278757	val-error:0.297302
# [930]	train-error:0.27878	val-error:0.297212
# [931]	train-error:0.278735	val-error:0.297122
# [932]	train-error:0.278667	val-error:0.296942
# [933]	train-error:0.278622	val-error:0.296942
# [934]	train-error:0.278577	val-error:0.296942
# [935]	train-error:0.278622	val-error:0.296942
# [936]	train-error:0.278577	val-error:0.296853
# [937]	train-error:0.278487	val-error:0.296763
# [938]	train-error:0.27851	val-error:0.296673
# [939]	train-error:0.278555	val-error:0.296673
# [940]	train-error:0.278487	val-error:0.296673
# [941]	train-error:0.278397	val-error:0.296493
# [942]	train-error:0.278262	val-error:0.296853
# [943]	train-error:0.27824	val-error:0.296942
# [944]	train-error:0.278128	val-error:0.296942
# [945]	train-error:0.27815	val-error:0.296853
# [946]	train-error:0.278015	val-error:0.296763
# [947]	train-error:0.27797	val-error:0.296763
# [948]	train-error:0.277993	val-error:0.296763
# [949]	train-error:0.27797	val-error:0.296853
# [950]	train-error:0.277903	val-error:0.296763
# [951]	train-error:0.277925	val-error:0.296493
# [952]	train-error:0.277858	val-error:0.296673
# [953]	train-error:0.277903	val-error:0.296583
# [954]	train-error:0.277858	val-error:0.296493
# [955]	train-error:0.277723	val-error:0.296493
# [956]	train-error:0.277768	val-error:0.296493
# [957]	train-error:0.2777	val-error:0.296403
# [958]	train-error:0.277723	val-error:0.296313
# [959]	train-error:0.277655	val-error:0.296403
# [960]	train-error:0.277678	val-error:0.296403
# [961]	train-error:0.277633	val-error:0.296313
# [962]	train-error:0.277655	val-error:0.296493
# [963]	train-error:0.27761	val-error:0.296223
# [964]	train-error:0.277655	val-error:0.296133
# [965]	train-error:0.277678	val-error:0.296223
# [966]	train-error:0.277588	val-error:0.296133
# [967]	train-error:0.277498	val-error:0.296043
# [968]	train-error:0.277363	val-error:0.296223
# [969]	train-error:0.277408	val-error:0.296223
# [970]	train-error:0.277431	val-error:0.296223
# [971]	train-error:0.277453	val-error:0.296133
# [972]	train-error:0.277408	val-error:0.296133
# [973]	train-error:0.277273	val-error:0.296133
# [974]	train-error:0.277251	val-error:0.295953
# [975]	train-error:0.277228	val-error:0.295863
# [976]	train-error:0.277206	val-error:0.295863
# [977]	train-error:0.277116	val-error:0.295863
# [978]	train-error:0.277093	val-error:0.295953
# [979]	train-error:0.277116	val-error:0.295953
# [980]	train-error:0.277138	val-error:0.295863
# [981]	train-error:0.277116	val-error:0.295953
# [982]	train-error:0.277093	val-error:0.295953
# [983]	train-error:0.277003	val-error:0.296043
# [984]	train-error:0.277116	val-error:0.296043
# [985]	train-error:0.277071	val-error:0.296043
# [986]	train-error:0.276936	val-error:0.296043
# [987]	train-error:0.276913	val-error:0.295953
# [988]	train-error:0.276846	val-error:0.295953
# [989]	train-error:0.276891	val-error:0.295953
# [990]	train-error:0.276823	val-error:0.295773
# [991]	train-error:0.276689	val-error:0.295863
# [992]	train-error:0.276711	val-error:0.295863
# [993]	train-error:0.276599	val-error:0.295773
# [994]	train-error:0.276554	val-error:0.295773
# [995]	train-error:0.276374	val-error:0.295773
# [996]	train-error:0.276261	val-error:0.295863
# [997]	train-error:0.276194	val-error:0.295863
# [998]	train-error:0.276194	val-error:0.295863
# [999]	train-error:0.276284	val-error:0.296043
# [1000]	train-error:0.276216	val-error:0.295953
# [1001]	train-error:0.276284	val-error:0.296043
# [1002]	train-error:0.276216	val-error:0.295863
# [1003]	train-error:0.276126	val-error:0.296043
# [1004]	train-error:0.276149	val-error:0.296043
# [1005]	train-error:0.276126	val-error:0.296043
# [1006]	train-error:0.276126	val-error:0.295863
# [1007]	train-error:0.276126	val-error:0.295863
# [1008]	train-error:0.276126	val-error:0.295953
# [1009]	train-error:0.276081	val-error:0.295863
# [1010]	train-error:0.275992	val-error:0.295863
# [1011]	train-error:0.275969	val-error:0.295683
# [1012]	train-error:0.275857	val-error:0.295773
# [1013]	train-error:0.275879	val-error:0.295773
# [1014]	train-error:0.275879	val-error:0.295773
# [1015]	train-error:0.275722	val-error:0.295953
# [1016]	train-error:0.275767	val-error:0.295863
# [1017]	train-error:0.275722	val-error:0.295953
# [1018]	train-error:0.275834	val-error:0.296043
# [1019]	train-error:0.275609	val-error:0.295953
# [1020]	train-error:0.275609	val-error:0.295953
# [1021]	train-error:0.275564	val-error:0.295683
# [1022]	train-error:0.275452	val-error:0.295144
# [1023]	train-error:0.275384	val-error:0.295324
# [1024]	train-error:0.275384	val-error:0.295144
# [1025]	train-error:0.275429	val-error:0.295234
# [1026]	train-error:0.275384	val-error:0.295324
# [1027]	train-error:0.275317	val-error:0.295234
# [1028]	train-error:0.27534	val-error:0.295144
# [1029]	train-error:0.27534	val-error:0.295054
# [1030]	train-error:0.275362	val-error:0.295054
# [1031]	train-error:0.27534	val-error:0.294964
# [1032]	train-error:0.275205	val-error:0.294784
# [1033]	train-error:0.275272	val-error:0.294784
# [1034]	train-error:0.275205	val-error:0.294874
# [1035]	train-error:0.275182	val-error:0.294874
# [1036]	train-error:0.275182	val-error:0.294784
# [1037]	train-error:0.275092	val-error:0.294784
# [1038]	train-error:0.275092	val-error:0.294874
# [1039]	train-error:0.275025	val-error:0.294514
# [1040]	train-error:0.274935	val-error:0.294694
# [1041]	train-error:0.274912	val-error:0.294694
# [1042]	train-error:0.27489	val-error:0.294874
# [1043]	train-error:0.274822	val-error:0.294694
# [1044]	train-error:0.274755	val-error:0.294694
# [1045]	train-error:0.274687	val-error:0.294604
# [1046]	train-error:0.274598	val-error:0.294514
# ...
# [1662]	train-error:0.255014	val-error:0.283813
# [1663]	train-error:0.255014	val-error:0.283903
# [1664]	train-error:0.254991	val-error:0.283813
# [1665]	train-error:0.254902	val-error:0.283813
# [1666]	train-error:0.254879	val-error:0.283723
# [1667]	train-error:0.254834	val-error:0.283723
# [1668]	train-error:0.254654	val-error:0.283723
# [1669]	train-error:0.254632	val-error:0.283543
# [1670]	train-error:0.254632	val-error:0.283543
# [1671]	train-error:0.254587	val-error:0.283633
# [1672]	train-error:0.254497	val-error:0.283813
# [1673]	train-error:0.254497	val-error:0.283813
# [1674]	train-error:0.254564	val-error:0.283813
# [1675]	train-error:0.254339	val-error:0.283723
# [1676]	train-error:0.254272	val-error:0.283993
# [1677]	train-error:0.25416	val-error:0.283813
# [1678]	train-error:0.254227	val-error:0.283903
# [1679]	train-error:0.254249	val-error:0.283813
# [1680]	train-error:0.254182	val-error:0.283633
# [1681]	train-error:0.254092	val-error:0.283633
# [1682]	train-error:0.25407	val-error:0.283543
# [1683]	train-error:0.25407	val-error:0.283633
# [1684]	train-error:0.25407	val-error:0.283813
# [1685]	train-error:0.254025	val-error:0.283813
# [1686]	train-error:0.25407	val-error:0.283813
# [1687]	train-error:0.254092	val-error:0.283903
# [1688]	train-error:0.25398	val-error:0.283813
# [1689]	train-error:0.254025	val-error:0.283633
# [1690]	train-error:0.25398	val-error:0.283633
# [1691]	train-error:0.253957	val-error:0.283633
# [1692]	train-error:0.25389	val-error:0.283543
# [1693]	train-error:0.253912	val-error:0.283453
# [1694]	train-error:0.25389	val-error:0.283453
# [1695]	train-error:0.253822	val-error:0.283543
# [1696]	train-error:0.253822	val-error:0.283543
# [1697]	train-error:0.253777	val-error:0.283453
# [1698]	train-error:0.2538	val-error:0.283453
# [1699]	train-error:0.2538	val-error:0.283273
# [1700]	train-error:0.253687	val-error:0.283273
# [1701]	train-error:0.253575	val-error:0.283183
# [1702]	train-error:0.253575	val-error:0.282914
# [1703]	train-error:0.253552	val-error:0.283004
# [1704]	train-error:0.253395	val-error:0.283094
# [1705]	train-error:0.25326	val-error:0.283004
# [1706]	train-error:0.253283	val-error:0.283004
# [1707]	train-error:0.253305	val-error:0.283004
# [1708]	train-error:0.253215	val-error:0.282734
# [1709]	train-error:0.253215	val-error:0.282734
# [1710]	train-error:0.253148	val-error:0.282734
# [1711]	train-error:0.253103	val-error:0.282914
# [1712]	train-error:0.253035	val-error:0.282914
# [1713]	train-error:0.253103	val-error:0.282914
# [1714]	train-error:0.25308	val-error:0.282734
# [1715]	train-error:0.253103	val-error:0.282734
# [1716]	train-error:0.25299	val-error:0.282554
# [1717]	train-error:0.253125	val-error:0.282644
# [1718]	train-error:0.253148	val-error:0.282554
# [1719]	train-error:0.253035	val-error:0.282554
# [1720]	train-error:0.253013	val-error:0.282554
# [1721]	train-error:0.252923	val-error:0.282644
# [1722]	train-error:0.252945	val-error:0.282734
# [1723]	train-error:0.252945	val-error:0.282644
# [1724]	train-error:0.253013	val-error:0.282644
# [1725]	train-error:0.252855	val-error:0.282644
# [1726]	train-error:0.252833	val-error:0.282644
# [1727]	train-error:0.252811	val-error:0.282644
# [1728]	train-error:0.252833	val-error:0.282554
# [1729]	train-error:0.252811	val-error:0.282644
# [1730]	train-error:0.252833	val-error:0.282644
# [1731]	train-error:0.252743	val-error:0.282734
# [1732]	train-error:0.252698	val-error:0.282644
# [1733]	train-error:0.252653	val-error:0.282464
# [1734]	train-error:0.252586	val-error:0.282554
# [1735]	train-error:0.252518	val-error:0.282284
# [1736]	train-error:0.252518	val-error:0.282284
# [1737]	train-error:0.252473	val-error:0.282284
# [1738]	train-error:0.252451	val-error:0.282194
# [1739]	train-error:0.252473	val-error:0.282284
# [1740]	train-error:0.252428	val-error:0.282284
# [1741]	train-error:0.252406	val-error:0.282374
# [1742]	train-error:0.252451	val-error:0.282104
# [1743]	train-error:0.252428	val-error:0.282014
# [1744]	train-error:0.252203	val-error:0.282284
# [1745]	train-error:0.252046	val-error:0.282194
# [1746]	train-error:0.252069	val-error:0.282374
# [1747]	train-error:0.252024	val-error:0.282374
# [1748]	train-error:0.252046	val-error:0.282194
# [1749]	train-error:0.252113	val-error:0.282284
# [1750]	train-error:0.252001	val-error:0.282374
# [1751]	train-error:0.251889	val-error:0.282374
# [1752]	train-error:0.251844	val-error:0.282284
# [1753]	train-error:0.251844	val-error:0.282284
# [1754]	train-error:0.251956	val-error:0.282284
# [1755]	train-error:0.251866	val-error:0.282284
# [1756]	train-error:0.251821	val-error:0.282374
# [1757]	train-error:0.251776	val-error:0.282374
# [1758]	train-error:0.251799	val-error:0.282374
# [1759]	train-error:0.251731	val-error:0.282374
# [1760]	train-error:0.251821	val-error:0.282194
# [1761]	train-error:0.251686	val-error:0.282194
# [1762]	train-error:0.251574	val-error:0.282194
# [1763]	train-error:0.251484	val-error:0.282194
# [1764]	train-error:0.251484	val-error:0.282194
# [1765]	train-error:0.251461	val-error:0.282194
# [1766]	train-error:0.251461	val-error:0.282104
# [1767]	train-error:0.251394	val-error:0.282014
# [1768]	train-error:0.251394	val-error:0.282014
# [1769]	train-error:0.251417	val-error:0.282014
# [1770]	train-error:0.251304	val-error:0.282104
# [1771]	train-error:0.251192	val-error:0.282014
# [1772]	train-error:0.251147	val-error:0.282014
# [1773]	train-error:0.251214	val-error:0.282014
# [1774]	train-error:0.251124	val-error:0.282104
# [1775]	train-error:0.251079	val-error:0.282014
# [1776]	train-error:0.251057	val-error:0.281924
# [1777]	train-error:0.251057	val-error:0.281745
# [1778]	train-error:0.250944	val-error:0.281565
# [1779]	train-error:0.251102	val-error:0.281655
# [1780]	train-error:0.251079	val-error:0.281835
# [1781]	train-error:0.251079	val-error:0.281835
# [1782]	train-error:0.251012	val-error:0.281655
# [1783]	train-error:0.250944	val-error:0.281565
# [1784]	train-error:0.250899	val-error:0.281655
# [1785]	train-error:0.250854	val-error:0.281655
# [1786]	train-error:0.250787	val-error:0.281565
# [1787]	train-error:0.250809	val-error:0.281655
# [1788]	train-error:0.250854	val-error:0.281835
# [1789]	train-error:0.250832	val-error:0.281924
# [1790]	train-error:0.250787	val-error:0.282014
# [1791]	train-error:0.250832	val-error:0.282014
# [1792]	train-error:0.250787	val-error:0.281924
# [1793]	train-error:0.250787	val-error:0.281835
# [1794]	train-error:0.250652	val-error:0.281835
# [1795]	train-error:0.250607	val-error:0.281655
# [1796]	train-error:0.250472	val-error:0.281745
# [1797]	train-error:0.25054	val-error:0.281655
# [1798]	train-error:0.250517	val-error:0.281655
# [1799]	train-error:0.250495	val-error:0.281745
# [1800]	train-error:0.250517	val-error:0.281835
# [1801]	train-error:0.25045	val-error:0.281745
# [1802]	train-error:0.250427	val-error:0.281655
# [1803]	train-error:0.250405	val-error:0.281565
# [1804]	train-error:0.250405	val-error:0.281565
# [1805]	train-error:0.250427	val-error:0.281565
# [1806]	train-error:0.250382	val-error:0.281565
# [1807]	train-error:0.25045	val-error:0.281565
# [1808]	train-error:0.25036	val-error:0.281475
# [1809]	train-error:0.250337	val-error:0.281655
# [1810]	train-error:0.250382	val-error:0.281475
# [1811]	train-error:0.250247	val-error:0.281475
# [1812]	train-error:0.250315	val-error:0.281475
# [1813]	train-error:0.250315	val-error:0.281295
# [1814]	train-error:0.25018	val-error:0.281205
# [1815]	train-error:0.25018	val-error:0.281115
# [1816]	train-error:0.250135	val-error:0.281025
# [1817]	train-error:0.250112	val-error:0.281025
# [1818]	train-error:0.250157	val-error:0.281115
# [1819]	train-error:0.250157	val-error:0.281115
# [1820]	train-error:0.25009	val-error:0.281205
# [1821]	train-error:0.250067	val-error:0.281205
# [1822]	train-error:0.249955	val-error:0.281115
# [1823]	train-error:0.249933	val-error:0.281025
# [1824]	train-error:0.249888	val-error:0.280935
# [1825]	train-error:0.249955	val-error:0.280935
# [1826]	train-error:0.249955	val-error:0.280935
# [1827]	train-error:0.24982	val-error:0.280755
# [1828]	train-error:0.249753	val-error:0.280755
# [1829]	train-error:0.24973	val-error:0.280755
# [1830]	train-error:0.24973	val-error:0.280845
# [1831]	train-error:0.24973	val-error:0.280845
# [1832]	train-error:0.249753	val-error:0.280755
# [1833]	train-error:0.24973	val-error:0.280845
# [1834]	train-error:0.249708	val-error:0.280845
# [1835]	train-error:0.249663	val-error:0.280845
# [1836]	train-error:0.249663	val-error:0.280845
# [1837]	train-error:0.249708	val-error:0.280755
# [1838]	train-error:0.249663	val-error:0.280845
# [1839]	train-error:0.249573	val-error:0.280845
# [1840]	train-error:0.249505	val-error:0.280665
# [1841]	train-error:0.24955	val-error:0.280755
# [1842]	train-error:0.249528	val-error:0.280845
# [1843]	train-error:0.249505	val-error:0.280845
# [1844]	train-error:0.249528	val-error:0.280845
# [1845]	train-error:0.249528	val-error:0.280845
# [1846]	train-error:0.249415	val-error:0.280845
# [1847]	train-error:0.249415	val-error:0.280845
# [1848]	train-error:0.24937	val-error:0.280755
# [1849]	train-error:0.249303	val-error:0.280665
# [1850]	train-error:0.249303	val-error:0.280576
# [1851]	train-error:0.249281	val-error:0.280576
# [1852]	train-error:0.249258	val-error:0.280665
# [1853]	train-error:0.249236	val-error:0.280576
# [1854]	train-error:0.249236	val-error:0.280576
# [1855]	train-error:0.249236	val-error:0.280576
# [1856]	train-error:0.249236	val-error:0.280576
# [1857]	train-error:0.249191	val-error:0.280486
# [1858]	train-error:0.249213	val-error:0.280576
# [1859]	train-error:0.249191	val-error:0.280486
# [1860]	train-error:0.249191	val-error:0.280755
# [1861]	train-error:0.249213	val-error:0.280665
# [1862]	train-error:0.249258	val-error:0.280665
# [1863]	train-error:0.249236	val-error:0.280486
# [1864]	train-error:0.249281	val-error:0.280486
# [1865]	train-error:0.249213	val-error:0.280486
# [1866]	train-error:0.249213	val-error:0.280576
# [1867]	train-error:0.249123	val-error:0.280576
# [1868]	train-error:0.249146	val-error:0.280576
# [1869]	train-error:0.249123	val-error:0.280576
# [1870]	train-error:0.249101	val-error:0.280665
# [1871]	train-error:0.249011	val-error:0.280306
# [1872]	train-error:0.248898	val-error:0.280396
# [1873]	train-error:0.248898	val-error:0.280396
# [1874]	train-error:0.248853	val-error:0.280396
# [1875]	train-error:0.248808	val-error:0.280396
# [1876]	train-error:0.248853	val-error:0.280396
# [1877]	train-error:0.248831	val-error:0.280396
# [1878]	train-error:0.248876	val-error:0.280216
# [1879]	train-error:0.248786	val-error:0.280126
# [1880]	train-error:0.248808	val-error:0.280126
# [1881]	train-error:0.248696	val-error:0.280036
# [1882]	train-error:0.248718	val-error:0.280036
# [1883]	train-error:0.248606	val-error:0.280216
# [1884]	train-error:0.248584	val-error:0.280126
# [1885]	train-error:0.248426	val-error:0.280126
# [1886]	train-error:0.248426	val-error:0.280126
# [1887]	train-error:0.248449	val-error:0.280126
# [1888]	train-error:0.248426	val-error:0.280126
# [1889]	train-error:0.248381	val-error:0.280126
# [1890]	train-error:0.248426	val-error:0.280216
# [1891]	train-error:0.248426	val-error:0.280126
# [1892]	train-error:0.248404	val-error:0.280126
# [1893]	train-error:0.248381	val-error:0.280126
# [1894]	train-error:0.248359	val-error:0.280126
# [1895]	train-error:0.248404	val-error:0.280216
# [1896]	train-error:0.248314	val-error:0.280306
# [1897]	train-error:0.248269	val-error:0.280486
# [1898]	train-error:0.248246	val-error:0.280486
# [1899]	train-error:0.248291	val-error:0.280486
# [1900]	train-error:0.248201	val-error:0.280486
# [1901]	train-error:0.248134	val-error:0.280486
# [1902]	train-error:0.248089	val-error:0.280396
# [1903]	train-error:0.248089	val-error:0.280306
# [1904]	train-error:0.248089	val-error:0.280306
# [1905]	train-error:0.248066	val-error:0.280306
# [1906]	train-error:0.248044	val-error:0.280306
# [1907]	train-error:0.248044	val-error:0.280306
# [1908]	train-error:0.247931	val-error:0.280216
# [1909]	train-error:0.247954	val-error:0.280126
# [1910]	train-error:0.247931	val-error:0.280036
# [1911]	train-error:0.247954	val-error:0.280036
# [1912]	train-error:0.247954	val-error:0.280036
# [1913]	train-error:0.247909	val-error:0.280126
# [1914]	train-error:0.247886	val-error:0.280126
# [1915]	train-error:0.247976	val-error:0.280126
# [1916]	train-error:0.247864	val-error:0.280126
# [1917]	train-error:0.247909	val-error:0.280216
# [1918]	train-error:0.247842	val-error:0.280126
# [1919]	train-error:0.247819	val-error:0.280126
# [1920]	train-error:0.247797	val-error:0.280036
# [1921]	train-error:0.247797	val-error:0.280036
# [1922]	train-error:0.247707	val-error:0.280036
# [1923]	train-error:0.247684	val-error:0.280036
# [1924]	train-error:0.247684	val-error:0.280036
# [1925]	train-error:0.247662	val-error:0.279946
# [1926]	train-error:0.247662	val-error:0.280036
# [1927]	train-error:0.247527	val-error:0.279856
# [1928]	train-error:0.247504	val-error:0.279946
# [1929]	train-error:0.247482	val-error:0.279856
# [1930]	train-error:0.247504	val-error:0.279856
# [1931]	train-error:0.247459	val-error:0.279856
# [1932]	train-error:0.247482	val-error:0.279766
# [1933]	train-error:0.247369	val-error:0.279766
# [1934]	train-error:0.247212	val-error:0.279766
# [1935]	train-error:0.247189	val-error:0.279586
# [1936]	train-error:0.247167	val-error:0.279856
# [1937]	train-error:0.247122	val-error:0.279766
# [1938]	train-error:0.247145	val-error:0.279766
# [1939]	train-error:0.2471	val-error:0.279676
# [1940]	train-error:0.247077	val-error:0.279676
# [1941]	train-error:0.247077	val-error:0.279946
# [1942]	train-error:0.247077	val-error:0.279856
# [1943]	train-error:0.247055	val-error:0.279766
# [1944]	train-error:0.24701	val-error:0.279766
# [1945]	train-error:0.246987	val-error:0.279676
# [1946]	train-error:0.246987	val-error:0.279676
# [1947]	train-error:0.246942	val-error:0.279676
# [1948]	train-error:0.246897	val-error:0.279676
# [1949]	train-error:0.246875	val-error:0.279586
# [1950]	train-error:0.246875	val-error:0.279676
# [1951]	train-error:0.24692	val-error:0.279317
# [1952]	train-error:0.24674	val-error:0.279406
# [1953]	train-error:0.246717	val-error:0.279317
# [1954]	train-error:0.246672	val-error:0.279137
# [1955]	train-error:0.24665	val-error:0.279227
# [1956]	train-error:0.24674	val-error:0.279047
# [1957]	train-error:0.246695	val-error:0.279227
# [1958]	train-error:0.246695	val-error:0.279317
# [1959]	train-error:0.246605	val-error:0.279317
# [1960]	train-error:0.246537	val-error:0.279227
# [1961]	train-error:0.246448	val-error:0.279137
# [1962]	train-error:0.246358	val-error:0.279227
# [1963]	train-error:0.24638	val-error:0.279227
# [1964]	train-error:0.24629	val-error:0.279317
# [1965]	train-error:0.246403	val-error:0.279227
# [1966]	train-error:0.246313	val-error:0.279317
# [1967]	train-error:0.246335	val-error:0.278957
# [1968]	train-error:0.24629	val-error:0.279047
# [1969]	train-error:0.246245	val-error:0.279047
# [1970]	train-error:0.246178	val-error:0.279227
# [1971]	train-error:0.246223	val-error:0.279227
# [1972]	train-error:0.246268	val-error:0.279137
# [1973]	train-error:0.2462	val-error:0.279137
# [1974]	train-error:0.246178	val-error:0.279317
# [1975]	train-error:0.24611	val-error:0.279227
# [1976]	train-error:0.24611	val-error:0.279227
# [1977]	train-error:0.24611	val-error:0.279137
# [1978]	train-error:0.245998	val-error:0.279227
# [1979]	train-error:0.24593	val-error:0.279137
# [1980]	train-error:0.245885	val-error:0.279137
# [1981]	train-error:0.245863	val-error:0.278957
# [1982]	train-error:0.245863	val-error:0.278867
# [1983]	train-error:0.245818	val-error:0.278777
# [1984]	train-error:0.245706	val-error:0.278777
# [1985]	train-error:0.245751	val-error:0.278777
# [1986]	train-error:0.245683	val-error:0.278687
# [1987]	train-error:0.245638	val-error:0.278687
# [1988]	train-error:0.245638	val-error:0.278687
# [1989]	train-error:0.245638	val-error:0.278687
# [1990]	train-error:0.245638	val-error:0.278687
# [1991]	train-error:0.245571	val-error:0.278597
# [1992]	train-error:0.245526	val-error:0.278597
# [1993]	train-error:0.245548	val-error:0.278597
# [1994]	train-error:0.245593	val-error:0.278597
# [1995]	train-error:0.245593	val-error:0.278507
# [1996]	train-error:0.245458	val-error:0.278507
# [1997]	train-error:0.245346	val-error:0.278507
# [1998]	train-error:0.245391	val-error:0.278507
# [1999]	train-error:0.245413	val-error:0.278327
# auc_value: 0.8965821439654379
# ks_values: 0.6330978997367606
# auc_value: 0.8187527934047941
# ks_values: 0.49098970417200916

# %%
sorted(model.get_fscore().items(),key=lambda x: x[1],reverse=True)
# Out:
# [('浏览行为数据_var', 1282),
#  ('bef_bill_creamo_used', 1124),
#  ('bef_bill_creamo_use_rate', 1026),
#  ('bef_bill_preloan_m3_sum', 979),
#  ('bef_bill_unc_cnt', 962),
#  ('aft_bill_creamo_use_rate', 958),
#  ('aft_bill_creamo_used', 870),
#  ('bef_bill_creused_gramo_min', 821),
#  ('bef_bill_creused_gramo_sum', 811),
#  ('bef_bill_creused_gramo_max', 796),
#  ('bef_browse_浏览子行为编号_10', 750),
#  ('bef_browse_浏览子行为编号_7', 731),
#  ('aft_bill_creused_gramo_max', 724),
#  ('bef_browse_浏览子行为编号_6', 712),
#  ('bef_browse_浏览子行为编号_8', 694),
#  ('bef_bill_con_cnt', 676),
#  ('bef_bill_inter_max', 648),
#  ('bef_bill_preloan_m3_cnt', 643),
#  ('bef_browse_浏览子行为编号_4', 636),
#  ('bef_bill_ovdu_cnt', 636),
#  ('bef_browse_浏览行为数据_m3_110', 634),
#  ('bef_bill_t0', 622),
#  ('aft_bill_creused_gramo_min', 615),
#  ('aft_bill_creused_gramo_sum', 601),
#  ('bef_browse_浏览行为数据_m3_101', 591),
#  ('bef_bank_inc_m3_max', 585),
#  ('bef_browse_浏览子行为编号_5', 584),
#  ('bef_browse_bro_act_cnt', 538),
#  ('bef_bank_inc_m3_min', 538),
#  ('bef_browse_浏览子行为编号_1', 528),
#  ('bef_bill_con_max_x', 499),
#  ('bef_bill_ovdu_m3_cnt', 495),
#  ('bef_bill_unc_m3_cnt', 493),
#  ('性别_0', 491),
#  ('bef_browse_浏览行为数据_m3_118', 487),
#  ('aft_bill_preloan_m3_sum', 483),
#  ('bef_browse_浏览行为数据_m3_189', 438),
#  ('bef_bill_t1', 436),
#  ('aft_bill_con_cnt', 430),
#  ('bef_browse_浏览子行为编号_d10_1', 423),
#  ('bef_browse_浏览子行为编号_m3_8', 423),
#  ('aft_bill_preloan_d30_sum', 418),
#  ('bef_browse_浏览子行为编号_m3_10', 417),
#  ('bef_browse_浏览子行为编号_m3_6', 415),
#  ('bef_bill_inter_cnt', 415),
#  ('bef_bill_amo_ava', 414),
#  ('bef_browse_浏览子行为编号_d10_7', 408),
#  ('aft_bill_preloan_d1_sum', 396),
#  ('bef_bank_inc_m3_count', 391),
#  ('bef_bill_preloan_bank_rate', 381),
#  ('bef_bill_t2', 379),
#  ('aft_bill_t10', 370),
#  ('bef_browse_浏览子行为编号_d10_10', 369),
#  ('bef_browse_浏览行为数据_m3_173', 368),
#  ('bef_browse_浏览子行为编号_m3_5', 359),
#  ('aft_bill_preloan_d10_sum', 358),
#  ('bef_browse_浏览子行为编号_m3_1', 354),
#  ('bef_bank_inc_sum', 349),
#  ('bef_bank_out_sum', 347),
#  ('aft_bill_t20', 344),
#  ('aft_bill_preloan_d20_sum', 341),
#  ('aft_bill_t30', 333),
#  ('aft_bill_preloan_d2_sum', 328),
#  ('aft_bill_inter_sum', 328),
#  ('bef_bank_out_m3_count', 326),
#  ('bef_browse_浏览行为数据_m3_164', 322),
#  ('aft_bill_inter_max', 322),
#  ('bef_browse_浏览子行为编号_3', 319),
#  ('bef_bank_ninc_m3_sum', 308),
#  ('aft_browse_bro_act_cnt', 306),
#  ('bef_bank_out_m1_sum', 303),
#  ('bef_browse_浏览子行为编号_d10_6', 302),
#  ('aft_bill_preloan_d0_sum', 300),
#  ('bef_bank_inc_m3_sum', 298),
#  ('bef_bank_inc_m1_sum', 295),
#  ('bef_browse_浏览子行为编号_m3_7', 295),
#  ('aft_bill_ovdu_d0_sum', 293),
#  ('aft_bill_preloan_m3_cnt', 293),
#  ('bef_browse_浏览子行为编号_m3_4', 292),
#  ('bef_browse_浏览子行为编号_d10_4', 285),
#  ('aft_bill_unc_cnt', 281),
#  ('bef_bank_salary_ave', 275),
#  ('性别_2', 266),
#  ('aft_bill_t1', 257),
#  ('bef_bill_con_max_y', 247),
#  ('aft_browse_浏览子行为编号_m3_1', 245),
#  ('bef_bank_out_m3_sum', 237),
#  ('教育程度_2', 234),
#  ('aft_browse_浏览行为数据_m3_101', 232),
#  ('aft_browse_浏览子行为编号_m3_10', 232),
#  ('aft_browse_浏览子行为编号_m3_5', 231),
#  ('aft_bill_preloan_bank_rate', 230),
#  ('bef_browse_浏览子行为编号_d10_5', 222),
#  ('aft_browse_浏览子行为编号_m3_6', 218),
#  ('aft_bill_t2', 218),
#  ('aft_bill_t0', 212),
#  ('aft_browse_浏览子行为编号_m3_4', 212),
#  ('aft_browse_浏览行为数据_m3_110', 209),
#  ('aft_bill_ovdu_d10_sum', 209),
#  ('aft_bill_con_max', 202),
#  ('aft_bill_ovdu_d30_sum', 201),
#  ('bef_bill_cre_bank_cnt', 189),
#  ('aft_bill_unc_m3_cnt', 189),
#  ('bef_browse_浏览子行为编号_d10_8', 176),
#  ('aft_browse_浏览行为数据_m3_189', 171),
#  ('教育程度_4', 165),
#  ('aft_browse_浏览行为数据_m3_173', 163),
#  ('aft_bank_inc_m3_max', 158),
#  ('aft_browse_浏览子行为编号_m3_8', 156),
#  ('bef_bank_salary_sum', 154),
#  ('户口类型_3', 153),
#  ('bef_browse_浏览子行为编号_m3_3', 152),
#  ('婚姻状态_1', 151),
#  ('bef_bill_creused_bank_cnt', 150),
#  ('aft_bill_ovdu_d2_sum', 146),
#  ('bef_bill_preloan_bank_cnt', 144),
#  ('aft_bill_ovdu_d20_sum', 143),
#  ('aft_browse_浏览子行为编号_m3_7', 142),
#  ('aft_bank_inc_m3_min', 141),
#  ('bef_bank_salary_inc_rate', 141),
#  ('aft_browse_浏览行为数据_m3_164', 140),
#  ('aft_bank_out_sum', 139),
#  ('户口类型_1', 138),
#  ('aft_browse_浏览子行为编号_10', 136),
#  ('aft_browse_浏览子行为编号_1', 136),
#  ('aft_browse_浏览子行为编号_5', 130),
#  ('aft_bill_ovdu_d1_sum', 129),
#  ('婚姻状态_2', 126),
#  ('aft_browse_浏览行为数据_m3_118', 126),
#  ('aft_bill_cre_bank_add', 125),
#  ('户口类型_2', 123),
#  ('aft_browse_浏览子行为编号_4', 121),
#  ('aft_bill_cre_bank_d10_cnt', 117),
#  ('aft_browse_浏览子行为编号_6', 117),
#  ('aft_bill_cre_bank_d30_cnt', 115),
#  ('aft_bill_cre_bank_cnt', 109),
#  ('aft_bank_out_m3_sum', 105),
#  ('aft_bill_creused_bank_cnt', 101),
#  ('职业_3', 100),
#  ('性别_1', 98),
#  ('aft_bank_out_m1_sum', 98),
#  ('户口类型_4', 94),
#  ('aft_bill_ovdu_cnt', 93),
#  ('bef_browse_浏览子行为编号_9', 93),
#  ('教育程度_3', 92),
#  ('aft_bank_inc_sum', 92),
#  ('职业_2', 92),
#  ('职业_4', 89),
#  ('aft_bill_amo_ava', 85),
#  ('婚姻状态_3', 85),
#  ('bef_browse_浏览子行为编号_d10_3', 85),
#  ('aft_browse_浏览子行为编号_8', 84),
#  ('aft_bank_inc_m1_sum', 83),
#  ('aft_browse_浏览子行为编号_m3_3', 83),
#  ('aft_bill_ovdu_m3_cnt', 78),
#  ('aft_bill_inter_cnt', 71),
#  ('aft_browse_浏览子行为编号_7', 68),
#  ('aft_bank_ninc_m3_sum', 62),
#  ('aft_bank_out_m3_count', 61),
#  ('aft_bank_inc_m3_sum', 57),
#  ('aft_bill_preloan_bank_cnt', 57),
#  ('职业_0', 54),
#  ('aft_bill_ovdu_d30_count', 49),
#  ('aft_bill_cre_bank_d0_cnt', 49),
#  ('aft_bill_ovdu_d10_count', 43),
#  ('aft_bank_inc_m3_count', 40),
#  ('aft_browse_浏览子行为编号_3', 40),
#  ('教育程度_1', 36),
#  ('aft_bill_ovdu_d0_count', 34),
#  ('aft_bill_ovdu_d20_count', 31),
#  ('教育程度_0', 30),
#  ('婚姻状态_4', 29),
#  ('aft_bank_salary_sum', 22),
#  ('aft_bill_ovdu_d2_count', 21),
#  ('婚姻状态_0', 20),
#  ('bef_browse_浏览子行为编号_d10_9', 19),
#  ('bef_browse_浏览子行为编号_m3_9', 15),
#  ('aft_bank_salary_inc_rate', 10),
#  ('婚姻状态_5', 9),
#  ('aft_bill_ovdu_d1_count', 8),
#  ('aft_bank_inc_m3_std', 8),
#  ('aft_browse_浏览子行为编号_m3_9', 7),
#  ('职业_1', 7),
#  ('bef_bank_inc_m3_std', 6),
#  ('户口类型_0', 6),
#  ('aft_browse_浏览子行为编号_9', 3),
#  ('bef_bill_amo_std', 3),
#  ('bef_browse_浏览子行为编号_m3_2', 3),
#  ('bef_bill_payst_cnt', 1)]

# %%
sorted(model.get_score(importance_type='gain').items(),key=lambda x: x[1],reverse=True)
# Out:
# [('aft_bill_t10', 644.3514395405398),
#  ('aft_bill_cre_bank_d10_cnt', 424.91575102564104),
#  ('aft_bill_preloan_d10_sum', 408.3525258100561),
#  ('aft_bill_t20', 404.1807284302319),
#  ('aft_bill_preloan_d20_sum', 219.0763839882697),
#  ('aft_bill_ovdu_d1_count', 172.36657249999996),
#  ('aft_bill_ovdu_d0_count', 142.8900344117647),
#  ('aft_bill_t2', 125.9886111926606),
#  ('aft_bill_cre_bank_d30_cnt', 125.78780339130431),
#  ('aft_bill_t30', 95.7914392192192),
#  ('aft_bill_ovdu_cnt', 84.07204827956988),
#  ('性别_0', 80.00189228105903),
#  ('aft_bill_preloan_d1_sum', 71.1346036616162),
#  ('aft_bill_t1', 61.287117392996166),
#  ('aft_bill_ovdu_d0_sum', 60.90524017064845),
#  ('aft_bill_preloan_d2_sum', 59.56505759146334),
#  ('aft_browse_浏览行为数据_m3_173', 57.92125),
#  ('aft_bill_ovdu_d10_sum', 57.87658961722487),
#  ('aft_bill_cre_bank_add', 57.12216047999994),
#  ('aft_bill_ovdu_d10_count', 56.70222860465117),
#  ('aft_bank_inc_m3_max', 52.59229012658227),
#  ('aft_bill_ovdu_d2_count', 52.05010619047618),
#  ('aft_browse_浏览行为数据_m3_164', 51.65036821428576),
#  ('性别_2', 49.206891278195506),
#  ('aft_bill_preloan_d30_sum', 45.978208277511925),
#  ('aft_bill_ovdu_d1_sum', 45.48531961240308),
#  ('bef_browse_浏览行为数据_m3_110', 44.41421044164038),
#  ('教育程度_2', 44.21652794871796),
#  ('bef_bill_ovdu_m3_cnt', 42.023884020202004),
#  ('bef_browse_浏览行为数据_m3_173', 41.41803641304347),
#  ('aft_browse_浏览行为数据_m3_101', 40.809505913793124),
#  ('aft_bill_ovdu_d2_sum', 39.03700616438357),
#  ('bef_browse_浏览行为数据_m3_101', 38.62563189509302),
#  ('aft_browse_浏览行为数据_m3_118', 38.011369603174586),
#  ('bef_browse_浏览子行为编号_d10_7', 36.89608142156863),
#  ('bef_browse_浏览子行为编号_d10_6', 36.4430427152318),
#  ('bef_browse_浏览行为数据_m3_118', 36.30972897330594),
#  ('bef_browse_浏览行为数据_m3_164', 34.65486142857143),
#  ('aft_bill_ovdu_d30_count', 34.00021714285715),
#  ('aft_bank_inc_m1_sum', 33.449806144578304),
#  ('aft_bank_out_m3_sum', 31.349176476190486),
#  ('aft_bank_inc_sum', 31.07903336956522),
#  ('aft_browse_浏览子行为编号_m3_6', 30.93924082568809),
#  ('aft_bill_ovdu_d30_sum', 30.78441149253732),
#  ('aft_browse_浏览行为数据_m3_110', 30.230565358851674),
#  ('aft_bank_out_sum', 29.80970431654676),
#  ('aft_bill_ovdu_d20_sum', 29.764403076923085),
#  ('性别_1', 29.662276122448976),
#  ('aft_browse_浏览子行为编号_m3_7', 29.468463098591542),
#  ('bef_browse_浏览子行为编号_m3_6', 28.90051161445784),
#  ('aft_bill_cre_bank_d0_cnt', 28.329991836734692),
#  ('aft_bill_preloan_d0_sum', 28.17717746666669),
#  ('aft_bank_inc_m3_sum', 28.04466912280703),
#  ('bef_bill_unc_cnt', 26.99811737006238),
#  ('aft_bill_unc_cnt', 26.73413202846975),
#  ('教育程度_4', 26.049360848484856),
#  ('aft_browse_浏览子行为编号_6', 25.91953470085472),
#  ('bef_bank_out_m3_count', 25.74991165644171),
#  ('bef_browse_浏览子行为编号_6', 25.69007507022475),
#  ('aft_bill_creamo_used', 25.686957735632202),
#  ('aft_browse_浏览子行为编号_1', 25.483073455882344),
#  ('aft_browse_浏览子行为编号_7', 25.250869999999995),
#  ('aft_browse_浏览子行为编号_m3_10', 24.591099784482783),
#  ('aft_bill_ovdu_d20_count', 24.20923870967741),
#  ('bef_browse_浏览子行为编号_10', 24.172749386666705),
#  ('bef_browse_浏览子行为编号_m3_7', 24.09500284745761),
#  ('aft_bank_out_m1_sum', 23.720432755102035),
#  ('bef_bank_inc_m3_count', 23.48361598465473),
#  ('aft_bill_creused_gramo_max', 23.45010542817683),
#  ('aft_browse_浏览子行为编号_10', 23.34333602941177),
#  ('aft_browse_浏览子行为编号_m3_4', 23.227734150943398),
#  ('aft_bill_cre_bank_cnt', 23.133710642201827),
#  ('aft_browse_浏览子行为编号_m3_1', 23.097506367346945),
#  ('aft_bank_out_m3_count', 22.59946573770492),
#  ('aft_browse_浏览子行为编号_4', 22.56617735537189),
#  ('bef_browse_浏览子行为编号_d10_10', 22.350405555555554),
#  ('bef_browse_浏览子行为编号_d10_4', 22.140622175438594),
#  ('bef_bank_salary_ave', 22.135842145454525),
#  ('bef_browse_浏览子行为编号_m3_10', 22.05518532374102),
#  ('bef_browse_浏览子行为编号_7', 21.842259548563643),
#  ('bef_browse_浏览子行为编号_8', 21.708583328530278),
#  ('bef_bank_inc_m3_min', 21.33430353159854),
#  ('aft_bill_preloan_m3_sum', 20.98609333333334),
#  ('bef_bill_unc_m3_cnt', 20.948007829614575),
#  ('bef_browse_浏览子行为编号_d10_1', 20.945653404255314),
#  ('bef_bill_creused_gramo_sum', 20.78578655980269),
#  ('bef_browse_浏览子行为编号_m3_4', 20.762060821917796),
#  ('bef_browse_浏览子行为编号_m3_8', 20.55880583924351),
#  ('aft_browse_bro_act_cnt', 20.493834313725475),
#  ('bef_bill_ovdu_cnt', 20.34312171383649),
#  ('aft_bill_creamo_use_rate', 20.18901217119),
#  ('aft_bill_creused_gramo_sum', 20.008759417637254),
#  ('bef_bank_out_m3_sum', 19.96190409282701),
#  ('bef_browse_浏览行为数据_m3_189', 19.858416164383566),
#  ('bef_bill_creused_gramo_max', 19.704274346733666),
#  ('bef_browse_浏览子行为编号_4', 19.5434829245283),
#  ('bef_bank_inc_m3_max', 19.431187333333327),
#  ('bef_bill_preloan_m3_sum', 19.21983127681306),
#  ('bef_browse_浏览子行为编号_d10_9', 18.829793157894734),
#  ('bef_bill_creused_gramo_min', 18.362609317904976),
#  ('aft_bill_preloan_m3_cnt', 18.326773105802037),
#  ('bef_bill_creamo_used', 18.163157295373676),
#  ('bef_browse_浏览子行为编号_m3_1', 18.101236920903954),
#  ('bef_bank_inc_sum', 18.025437679083105),
#  ('bef_bank_inc_m3_sum', 18.002086140939614),
#  ('婚姻状态_2', 17.842234285714298),
#  ('aft_bill_preloan_bank_rate', 17.728657304347834),
#  ('婚姻状态_1', 17.658568543046357),
#  ('aft_bill_creused_gramo_min', 17.63513492682928),
#  ('aft_browse_浏览子行为编号_m3_5', 17.522075541125545),
#  ('aft_bill_t0', 17.355328160377365),
#  ('bef_bill_con_cnt', 17.347953786982238),
#  ('浏览行为数据_var', 17.332584024961044),
#  ('aft_bill_preloan_bank_cnt', 17.228449473684215),
#  ('bef_bill_preloan_m3_cnt', 17.19400129082425),
#  ('aft_browse_浏览子行为编号_m3_3', 17.131099759036147),
#  ('bef_bill_t2', 17.126946992084434),
#  ('bef_bill_t1', 17.115033944954142),
#  ('bef_browse_浏览子行为编号_1', 17.086391325757585),
#  ('bef_browse_bro_act_cnt', 17.029165836431226),
#  ('bef_bill_inter_cnt', 16.95655098795181),
#  ('bef_bill_inter_max', 16.85754856481484),
#  ('bef_bill_t0', 16.847865803858515),
#  ('bef_browse_浏览子行为编号_5', 16.689333544520537),
#  ('bef_bank_out_sum', 16.66840409221902),
#  ('aft_bill_con_cnt', 16.48870981395351),
#  ('aft_browse_浏览行为数据_m3_189', 16.444350116959058),
#  ('bef_bank_out_m1_sum', 16.371834191419143),
#  ('aft_browse_浏览子行为编号_5', 16.350854461538464),
#  ('aft_bill_inter_sum', 16.343822103658553),
#  ('aft_bill_creused_bank_cnt', 16.34323237623762),
#  ('户口类型_1', 16.310819130434776),
#  ('bef_bill_cre_bank_cnt', 16.302004126984137),
#  ('bef_bill_creamo_use_rate', 16.12750280701753),
#  ('bef_bill_amo_ava', 16.115185338164256),
#  ('户口类型_2', 16.06139414634146),
#  ('aft_bill_con_max', 15.93828024752476),
#  ('bef_browse_浏览子行为编号_3', 15.91498275862069),
#  ('bef_browse_浏览子行为编号_d10_5', 15.63949702702703),
#  ('bef_bill_con_max_x', 15.624218456913844),
#  ('bef_browse_浏览子行为编号_m3_5', 15.616729610027855),
#  ('aft_bill_inter_cnt', 15.556589154929581),
#  ('bef_bill_con_max_y', 15.532196801619431),
#  ('户口类型_3', 15.490634444444435),
#  ('aft_bill_unc_m3_cnt', 15.364692275132288),
#  ('bef_browse_浏览子行为编号_9', 15.277731827956995),
#  ('bef_bank_inc_m1_sum', 15.202629661016939),
#  ('教育程度_0', 15.167987666666667),
#  ('aft_bill_inter_max', 15.051048447204984),
#  ('bef_bank_ninc_m3_sum', 14.98680850649351),
#  ('职业_4', 14.944574044943822),
#  ('bef_browse_浏览子行为编号_d10_8', 14.914689545454547),
#  ('职业_2', 14.804609347826087),
#  ('aft_browse_浏览子行为编号_3', 14.661814750000008),
#  ('bef_bill_preloan_bank_cnt', 14.23741958333334),
#  ('bef_bill_preloan_bank_rate', 14.22976881889764),
#  ('bef_bill_creused_bank_cnt', 13.925487799999997),
#  ('职业_0', 13.907714074074079),
#  ('aft_bank_inc_m3_count', 13.735340750000002),
#  ('bef_browse_浏览子行为编号_d10_3', 13.733149647058822),
#  ('aft_bill_ovdu_m3_cnt', 13.35505551282051),
#  ('aft_browse_浏览子行为编号_m3_8', 13.218737884615381),
#  ('教育程度_1', 13.197766944444444),
#  ('bef_bank_salary_sum', 13.069528896103899),
#  ('bef_browse_浏览子行为编号_m3_3', 12.789234868421051),
#  ('aft_browse_浏览子行为编号_8', 12.654244047619041),
#  ('职业_3', 12.616926246999997),
#  ('婚姻状态_0', 12.5816895),
#  ('户口类型_4', 12.579229574468084),
#  ('bef_bank_salary_inc_rate', 12.430259007092195),
#  ('aft_bill_amo_ava', 12.42977976470588),
#  ('aft_bank_inc_m3_min', 12.427725673758871),
#  ('婚姻状态_3', 12.058652352941175),
#  ('教育程度_3', 11.866731304347827),
#  ('aft_bank_salary_sum', 11.435324999999999),
#  ('bef_browse_浏览子行为编号_m3_9', 11.379097999999999),
#  ('aft_browse_浏览子行为编号_9', 11.081416666666668),
#  ('户口类型_0', 10.567493333333333),
#  ('aft_browse_浏览子行为编号_m3_9', 10.387145714285717),
#  ('婚姻状态_4', 10.270553448275864),
#  ('aft_bank_ninc_m3_sum', 9.373817903225802),
#  ('aft_bank_salary_inc_rate', 8.973362999999999),
#  ('bef_bank_inc_m3_std', 8.959435),
#  ('aft_bank_inc_m3_std', 8.73740875),
#  ('职业_1', 8.716165714285713),
#  ('bef_bill_amo_std', 6.801950000000001),
#  ('婚姻状态_5', 5.768027777777778),
#  ('bef_bill_payst_cnt', 3.25239),
#  ('bef_browse_浏览子行为编号_m3_2', 2.98023)]

# %%
# 预测及输出文件
pred=model.predict(test_dm)

res=test_set.copy()
res['pred']=pred
res=res[['id','pred']]
res.loc[res['pred']>1,'pred']=1
res.loc[res['pred']<0,'pred']=0

res.columns=['userid','probability']
res.to_csv('./data/predict_result/RES_TEST.csv',sep=',',index=False)

# %%
# fea_list
fea_list=['aft_bill_t2'
 ,'aft_bill_t1'
 ,'aft_bill_t0'
 ,'aft_bill_cre_bank_cnt'
 ,'性别_0'
 ,'aft_bill_ovdu_cnt'
 ,'aft_bill_con_cnt'
 ,'aft_bill_ovdu_m3_cnt'
 ,'aft_browse_浏览行为数据_m3_164'
 ,'aft_browse_浏览行为数据_m3_173'
 ,'aft_bill_con_max_x'
 ,'aft_bill_preloan_m3_cnt'
 ,'bef_browse_浏览行为数据_m3_101'
 ,'bef_browse_浏览行为数据_m3_110'
 ,'性别_2'
 ,'aft_bank_inc_m3_max'
 ,'bef_browse_浏览行为数据_m3_164'
 ,'bef_browse_浏览行为数据_m3_173'
 ,'bef_bill_ovdu_m3_cnt'
 ,'aft_browse_浏览行为数据_m3_101'
 ,'aft_bill_creamo_used'
 ,'性别_1'
 ,'教育程度_2'
 ,'bef_browse_浏览行为数据_m3_118'
 ,'aft_bank_inc_m3_sum'
 ,'aft_bank_out_m3_sum'
 ,'bef_browse_浏览子行为编号_m3_6'
 ,'aft_browse_浏览行为数据_m3_118'
 ,'aft_browse_浏览行为数据_m3_110'
 ,'aft_bill_preloan_m3_sum'
 ,'aft_bank_inc_m1_sum'
 ,'aft_bank_out_sum'
 ,'aft_bank_inc_sum'
 ,'bef_browse_浏览子行为编号_10'
 ,'aft_browse_浏览子行为编号_m3_7'
 ,'bef_bill_unc_cnt'
 ,'aft_browse_浏览子行为编号_6'
 ,'bef_browse_浏览子行为编号_6'
 ,'aft_bill_unc_cnt'
 ,'aft_browse_浏览子行为编号_m3_6'
 ,'bef_browse_浏览子行为编号_m3_7'
 ,'aft_browse_浏览子行为编号_1'
 ,'aft_browse_浏览子行为编号_7'
 ,'aft_bank_out_m1_sum'
 ,'bef_browse_浏览行为数据_m3_189'
 ,'bef_browse_浏览子行为编号_m3_10'
 ,'aft_browse_浏览子行为编号_m3_1'
 ,'教育程度_4'
 ,'bef_bank_inc_m3_count'
 ,'bef_bank_out_m3_count'
 ,'aft_browse_浏览子行为编号_4'
 ,'aft_browse_bro_act_cnt'
 ,'bef_browse_浏览子行为编号_8'
 ,'bef_bill_unc_m3_cnt'
 ,'aft_bill_creused_gramo_sum'
 ,'aft_bank_out_m3_count'
 ,'bef_bank_inc_m3_max'
 ,'aft_bill_creused_gramo_max'
 ,'aft_browse_浏览子行为编号_m3_10'
 ,'bef_bank_inc_m3_min'
 ,'aft_bill_unc_m3_cnt'
 ,'bef_bill_ovdu_cnt'
 ,'bef_bank_salary_ave'
 ,'bef_bill_creused_gramo_max'
 ,'bef_browse_浏览子行为编号_m3_4'
 ,'bef_bill_creused_gramo_sum'
 ,'aft_bill_creused_bank_cnt'
 ,'bef_browse_浏览子行为编号_m3_8'
 ,'bef_browse_浏览子行为编号_7'
 ,'bef_browse_浏览子行为编号_4'
 ,'aft_bill_creamo_use_rate'
 ,'aft_browse_浏览子行为编号_m3_4'
 ,'bef_browse_浏览子行为编号_m3_1'
 ,'aft_browse_浏览子行为编号_10'
 ,'bef_bill_creused_gramo_min'
 ,'aft_bill_preloan_bank_cnt'
 ,'bef_bill_creamo_used'
 ,'bef_bill_preloan_m3_sum'
 ,'bef_bank_inc_sum'
 ,'aft_browse_浏览子行为编号_m3_3'
 ,'bef_bank_out_m3_sum'
 ,'bef_bank_inc_m3_sum'
 ,'aft_bill_preloan_bank_rate'
 ,'bef_browse_浏览子行为编号_5'
 ,'bef_bill_cre_bank_cnt'
 ,'婚姻状态_1'
 ,'bef_bank_out_sum'
 ,'aft_bill_creused_gramo_min'
 ,'bef_bill_preloan_m3_cnt'
 ,'aft_browse_浏览子行为编号_3'
 ,'婚姻状态_2'
 ,'bef_bank_ninc_m3_sum'
 ,'bef_bill_inter_max'
 ,'bef_bill_t1'
 ,'户口类型_2'
 ,'bef_bill_inter_cnt'
 ,'bef_bill_preloan_bank_cnt'
 ,'bef_browse_浏览子行为编号_1'
 ,'aft_browse_浏览子行为编号_5'
 ,'bef_bill_t0'
 ,'bef_browse_bro_act_cnt'
 ,'bef_bank_out_m1_sum'
 ,'bef_bill_t2'
 ,'bef_bill_con_cnt'
 ,'bef_bill_con_max_y'
 ,'aft_browse_浏览行为数据_m3_189'
 ,'bef_bill_amo_ava'
 ,'bef_browse_浏览子行为编号_m3_5'
 ,'aft_bill_inter_max'
 ,'aft_browse_浏览子行为编号_m3_5'
 ,'户口类型_1'
 ,'bef_browse_浏览子行为编号_3'
 ,'bef_browse_浏览子行为编号_9'
 ,'bef_bill_creamo_use_rate'
 ,'aft_bill_amo_ava'
 ,'bef_bank_salary_inc_rate'
 ,'职业_2'
 ,'户口类型_3'
 ,'aft_browse_浏览子行为编号_8'
 ,'bef_bill_con_max_x'
 ,'aft_bill_con_max_y'
 ,'aft_browse_浏览子行为编号_m3_8'
 ,'aft_bill_inter_cnt'
]
